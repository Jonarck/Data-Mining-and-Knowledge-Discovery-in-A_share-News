# %% [markdown]
# # DSAA 5002 - Data Mining and Knowledge Discovery in Data Science
# ---

# %% [markdown]
# # Task 1 (50 marks) Data Preprocessing and Analysis
#
# **Background:**
# **Assuming you are a sentiment analyst at a securities firm, your task is to assess the impact of each news article on the A-share listed companies explicitly mentioned.**

# %% [markdown]
# # Q1. Data Preprocessing - Noise Removal
# ---
#
# ## 1. Search by Rules of Name Trigger Words for Training domain set
# - Generate a "training domain set" (i.e., a "completely accurate set of relevancy") using rules under the tightest boundary.
# - Record the relevant stock names in each news-row.
#
# ### 1.1. Trigger Words

# %%
import json
import jieba
import re

# %%
def create_company_lookup(company_list):
    # Use a set deduplicating the items
    company_set = set()
    for company in company_list:
        company_set.add(company["name"])
        
    print("The number of company name: {}".format(len(company_list)))
    print("The number of company name to be searched: {}".format(len(company_set)))
    return company_set

# Create the Trigger Words Set of A_share Company name
with open("News_input\\A_share_list\\new_A_share_list.json", "r", encoding="utf-8") as file:
    a_share_list = json.load(file)
company_set = create_company_lookup(a_share_list)
# Out:
# The number of company name: 4654
# The number of company name to be searched: 4625

# %%
def find_duplicate_companies(company_list):
    seen = set()
    duplicate_companies = set()

    for company in company_list:
        company_name = company["name"]
        if company_name in seen:
            duplicate_companies.add(company_name)
        else:
            seen.add(company_name)

    return duplicate_companies

# Call this function to find duplicate company names
duplicate_companies = find_duplicate_companies(a_share_list)

print("Duplicate company names:", duplicate_companies)
print("Number of duplicate company names:", len(duplicate_companies))
# Out:
# Duplicate company names: {'震安科技', '宏达新材', '爱迪尔', '科融环境', '东方明珠', '建研集团', '创业黑马', '金通灵', '厚普股份', '航发控制', '银泰资源', '风语筑', '中铁工业', '退市博元', '慈铭体检', '奇信股份', '当代明诚', '新黄浦', '恒林股份', '吉宏股份', '奥赛康', '一心堂', '华峰超纤', '三丰智能', '贤丰控股', '康达新材', '长江润发', '贝因美'}
# Number of duplicate company names: 28

# %% [markdown]
# ### 1.2. Noise Removal for Training domain set

# %%
from concurrent.futures import ThreadPoolExecutor
# from tqdm import tqdm
import pandas as pd
import threading

# Create a global lock to ensure thread safety
lock = threading.Lock()

# Function to process a single row of data
def process_row(row, company_set, result_list, drop_list):
    title = row["Title"]
    news_content = row["NewsContent"]
   
    if pd.notna(title) and pd.notna(news_content):      
        news = title + news_content
        if any(company in news for company in company_set):
            # Combine the four columns of this row into one
            combined_row = {
                "NewsID": row["NewsID"],
                "Title": title,
                "NewsContent": news_content,
                "NewsSource": row["NewsSource"],
            }
            with lock:
                result_list.append(combined_row)  # Add the row that meets the condition to the result list
        else:
            # Combine the four columns of this row into one
            combined_row = {
                "NewsID": row["NewsID"],
                "Title": title,
                "NewsContent": news_content,
                "NewsSource": row["NewsSource"]
            }
            with lock:
                drop_list.append(combined_row)  # Add the row that meets the condition to the drop list

# Main processing function
def process_data(start, end, full_data, company_set, result_list, drop_list):
    for i in range(start, end):
        if i % 1000 == 0:
            print("{} rows have been done".format(i))
            print("--- ")
        process_row(full_data.iloc[i], company_set, result_list, drop_list)

# %%
# Read an Excel file
full_data = pd.read_excel("News_input\\News.xlsx")

# %%
# Splitting data into chunks
num_threads = 21  # Specify the number of threads
chunk_size = len(full_data) // num_threads

threads = []
result_list = []
drop_list= []
print("Processing data with {} threads...".format(num_threads))

for i in range(num_threads):
    start = i * chunk_size
    end = (i + 1) * chunk_size if i < num_threads - 1 else len(full_data)
    thread = threading.Thread(target=process_data, args=(start, end, full_data, company_set, result_list, drop_list))
    threads.append(thread)
    print("Thread {} is processing rows {} to {}...".format(i + 1, start, end))
    
for thread in threads:
    thread.start()

for thread in threads:
    thread.join()

print("All threads have finished processing.\n")

print("Before selected by Rule, number of news is: {}".format(len(full_data)))
print("After selected by Rule, number of news is: {}".format(len(result_list)))
print("Droped by Rule, number of news is: {}".format(len(drop_list)))

# Merging results
result_df = pd.concat([pd.DataFrame(result_list)])
drop_df = pd.concat([pd.DataFrame(drop_list)])
# Out:
# Processing data with 21 threads...
# Thread 1 is processing rows 0 to 49382...
# Thread 2 is processing rows 49382 to 98764...
# Thread 3 is processing rows 98764 to 148146...
# Thread 4 is processing rows 148146 to 197528...
# Thread 5 is processing rows 197528 to 246910...
# Thread 6 is processing rows 246910 to 296292...
# Thread 7 is processing rows 296292 to 345674...
# Thread 8 is processing rows 345674 to 395056...
# Thread 9 is processing rows 395056 to 444438...
# Thread 10 is processing rows 444438 to 493820...
# Thread 11 is processing rows 493820 to 543202...
# Thread 12 is processing rows 543202 to 592584...
# Thread 13 is processing rows 592584 to 641966...
# Thread 14 is processing rows 641966 to 691348...
# Thread 15 is processing rows 691348 to 740730...
# Thread 16 is processing rows 740730 to 790112...
# Thread 17 is processing rows 790112 to 839494...
# Thread 18 is processing rows 839494 to 888876...
# Thread 19 is processing rows 888876 to 938258...
# Thread 20 is processing rows 938258 to 987640...
# Thread 21 is processing rows 987640 to 1037035...
# 0 rows have been done
# ---
# 642000 rows have been done
# ---
# 99000 rows have been done
# ---
# 247000 rows have been done
# ---
# 494000 rows have been done
# ---
# 889000 rows have been done
# ---
# 346000 rows have been done
# ---
# 198000 rows have been done
# ---
# 741000 rows have been done
# ---
# 593000 rows have been done
# ---
# 988000 rows have been done
# ---
# 50000 rows have been done
# ---
# 445000 rows have been done
# ---
# 840000 rows have been done
# ---
# 149000 rows have been done
# ---
# 297000 rows have been done
# ---
# 692000 rows have been done
# ---
# 544000 rows have been done
# ---
# 939000 rows have been done
# ---
# 1000 rows have been done
# ---
# 396000 rows have been done
# ---
# 791000 rows have been done
# ---
# 643000 rows have been done
# ---
# 100000 rows have been done
# ---
# 248000 rows have been done
# ---
# 495000 rows have been done
# ---
# 890000 rows have been done
# ---
# 347000 rows have been done
# ---
# 199000 rows have been done
# ---
# 742000 rows have been done
# ---
# 594000 rows have been done
# ---
# 989000 rows have been done
# ---
# 51000 rows have been done
# ---
# 446000 rows have been done
# ---
# 841000 rows have been done
# ---
# 150000 rows have been done
# ---
# 298000 rows have been done
# ---
# 693000 rows have been done
# ---
# 545000 rows have been done
# ---
# 940000 rows have been done
# ---
# 2000 rows have been done
# ---
# 397000 rows have been done
# ---
# 792000 rows have been done
# ---
# 644000 rows have been done
# ---
# 101000 rows have been done
# ---
# 249000 rows have been done
# ---
# 496000 rows have been done
# ---
# 891000 rows have been done
# ---
# 348000 rows have been done
# ---
# 200000 rows have been done
# ---
# 743000 rows have been done
# ---
# 595000 rows have been done
# ---
# 990000 rows have been done
# ---
# 52000 rows have been done
# ---
# 447000 rows have been done
# ---
# 842000 rows have been done
# ---
# 151000 rows have been done
# ---
# 299000 rows have been done
# ---
# 694000 rows have been done
# ---
# 546000 rows have been done
# ---
# 941000 rows have been done
# ---
# 3000 rows have been done
# ---
# 398000 rows have been done
# ---
# 793000 rows have been done
# ---
# 645000 rows have been done
# ---
# 102000 rows have been done
# ---
# 250000 rows have been done
# ---
# 497000 rows have been done
# ---
# 892000 rows have been done
# ---
# 349000 rows have been done
# ---
# 201000 rows have been done
# ---
# 744000 rows have been done
# ---
# 596000 rows have been done
# ---
# 991000 rows have been done
# ---
# 53000 rows have been done
# ---
# 448000 rows have been done
# ---
# 843000 rows have been done
# ---
# 152000 rows have been done
# ---
# 300000 rows have been done
# ---
# 695000 rows have been done
# ---
# 547000 rows have been done
# ---
# 942000 rows have been done
# ---
# 4000 rows have been done
# ---
# 399000 rows have been done
# ---
# 794000 rows have been done
# ---
# 646000 rows have been done
# ---
# 103000 rows have been done
# ---
# 251000 rows have been done
# ---
# 498000 rows have been done
# ---
# 893000 rows have been done
# ---
# 350000 rows have been done
# ---
# 202000 rows have been done
# ---
# 745000 rows have been done
# ---
# 597000 rows have been done
# ---
# 992000 rows have been done
# ---
# 54000 rows have been done
# ---
# 449000 rows have been done
# ---
# 844000 rows have been done
# ---
# 153000 rows have been done
# ---
# 301000 rows have been done
# ---
# 696000 rows have been done
# ---
# 548000 rows have been done
# ---
# 943000 rows have been done
# ---
# 5000 rows have been done
# ---
# 400000 rows have been done
# ---
# 795000 rows have been done
# ---
# 647000 rows have been done
# ---
# 104000 rows have been done
# ---
# 252000 rows have been done
# ---
# 499000 rows have been done
# ---
# 894000 rows have been done
# ---
# 203000 rows have been done
# ---
# 351000 rows have been done
# ---
# 746000 rows have been done
# ---
# 598000 rows have been done
# ---
# 993000 rows have been done
# ---
# 55000 rows have been done
# ---
# 450000 rows have been done
# ---
# 845000 rows have been done
# ---
# 154000 rows have been done
# ---
# 302000 rows have been done
# ---
# 697000 rows have been done
# ---
# 549000 rows have been done
# ---
# 944000 rows have been done
# ---
# 6000 rows have been done
# ---
# 401000 rows have been done
# ---
# 796000 rows have been done
# ---
# 648000 rows have been done
# ---
# 105000 rows have been done
# ---
# 253000 rows have been done
# ---
# 500000 rows have been done
# ---
# 895000 rows have been done
# ---
# 204000 rows have been done
# ---
# 352000 rows have been done
# ---
# 747000 rows have been done
# ---
# 599000 rows have been done
# ---
# 994000 rows have been done
# ---
# 56000 rows have been done
# ---
# 451000 rows have been done
# ---
# 846000 rows have been done
# ---
# 155000 rows have been done
# ---
# 303000 rows have been done
# ---
# 698000 rows have been done
# ---
# 550000 rows have been done
# ---
# 945000 rows have been done
# ---
# 7000 rows have been done
# ---
# 402000 rows have been done
# ---
# 797000 rows have been done
# ---
# 649000 rows have been done
# ---
# 106000 rows have been done
# ---
# 254000 rows have been done
# ---
# 501000 rows have been done
# ---
# 896000 rows have been done
# ---
# 205000 rows have been done
# ---
# 353000 rows have been done
# ---
# 748000 rows have been done
# ---
# 600000 rows have been done
# ---
# 995000 rows have been done
# ---
# 57000 rows have been done
# ---
# 452000 rows have been done
# ---
# 847000 rows have been done
# ---
# 156000 rows have been done
# ---
# 304000 rows have been done
# ---
# 699000 rows have been done
# ---
# 551000 rows have been done
# ---
# 946000 rows have been done
# ---
# 8000 rows have been done
# ---
# 403000 rows have been done
# ---
# 798000 rows have been done
# ---
# 650000 rows have been done
# ---
# 107000 rows have been done
# ---
# 255000 rows have been done
# ---
# 502000 rows have been done
# ---
# 897000 rows have been done
# ---
# 206000 rows have been done
# ---
# 354000 rows have been done
# ---
# 749000 rows have been done
# ---
# 601000 rows have been done
# ---
# 996000 rows have been done
# ---
# 58000 rows have been done
# ---
# 453000 rows have been done
# ---
# 848000 rows have been done
# ---
# 157000 rows have been done
# ---
# 305000 rows have been done
# ---
# 700000 rows have been done
# ---
# 552000 rows have been done
# ---
# 947000 rows have been done
# ---
# 9000 rows have been done
# ---
# 404000 rows have been done
# ---
# 799000 rows have been done
# ---
# 651000 rows have been done
# ---
# 108000 rows have been done
# ---
# 256000 rows have been done
# ---
# 503000 rows have been done
# ---
# 898000 rows have been done
# ---
# 207000 rows have been done
# ---
# 355000 rows have been done
# ---
# 750000 rows have been done
# ---
# 602000 rows have been done
# ---
# 997000 rows have been done
# ---
# 59000 rows have been done
# ---
# 454000 rows have been done
# ---
# 849000 rows have been done
# ---
# 158000 rows have been done
# ---
# 306000 rows have been done
# ---
# 701000 rows have been done
# ---
# 553000 rows have been done
# ---
# 948000 rows have been done
# ---
# 10000 rows have been done
# ---
# 405000 rows have been done
# ---
# 800000 rows have been done
# ---
# 652000 rows have been done
# ---
# 109000 rows have been done
# ---
# 257000 rows have been done
# ---
# 504000 rows have been done
# ---
# 899000 rows have been done
# ---
# 208000 rows have been done
# ---
# 356000 rows have been done
# ---
# 751000 rows have been done
# ---
# 603000 rows have been done
# ---
# 998000 rows have been done
# ---
# 60000 rows have been done
# ---
# 455000 rows have been done
# ---
# 850000 rows have been done
# ---
# 159000 rows have been done
# ---
# 307000 rows have been done
# ---
# 702000 rows have been done
# ---
# 554000 rows have been done
# ---
# 949000 rows have been done
# ---
# 11000 rows have been done
# ---
# 406000 rows have been done
# ---
# 801000 rows have been done
# ---
# 653000 rows have been done
# ---
# 110000 rows have been done
# ---
# 258000 rows have been done
# ---
# 505000 rows have been done
# ---
# 900000 rows have been done
# ---
# 209000 rows have been done
# ---
# 357000 rows have been done
# ---
# 752000 rows have been done
# ---
# 604000 rows have been done
# ---
# 999000 rows have been done
# ---
# 61000 rows have been done
# ---
# 456000 rows have been done
# ---
# 851000 rows have been done
# ---
# 160000 rows have been done
# ---
# 308000 rows have been done
# ---
# 703000 rows have been done
# ---
# 555000 rows have been done
# ---
# 950000 rows have been done
# ---
# 12000 rows have been done
# ---
# 407000 rows have been done
# ---
# 802000 rows have been done
# ---
# 654000 rows have been done
# ---
# 111000 rows have been done
# ---
# 259000 rows have been done
# ---
# 506000 rows have been done
# ---
# 901000 rows have been done
# ---
# 210000 rows have been done
# ---
# 358000 rows have been done
# ---
# 753000 rows have been done
# ---
# 605000 rows have been done
# ---
# 1000000 rows have been done
# ---
# 62000 rows have been done
# ---
# 457000 rows have been done
# ---
# 852000 rows have been done
# ---
# 161000 rows have been done
# ---
# 309000 rows have been done
# ---
# 704000 rows have been done
# ---
# 556000 rows have been done
# ---
# 951000 rows have been done
# ---
# 13000 rows have been done
# ---
# 408000 rows have been done
# ---
# 803000 rows have been done
# ---
# 655000 rows have been done
# ---
# 112000 rows have been done
# ---
# 260000 rows have been done
# ---
# 507000 rows have been done
# ---
# 902000 rows have been done
# ---
# 211000 rows have been done
# ---
# 359000 rows have been done
# ---
# 754000 rows have been done
# ---
# 606000 rows have been done
# ---
# 1001000 rows have been done
# ---
# 63000 rows have been done
# ---
# 458000 rows have been done
# ---
# 853000 rows have been done
# ---
# 162000 rows have been done
# ---
# 310000 rows have been done
# ---
# 705000 rows have been done
# ---
# 557000 rows have been done
# ---
# 952000 rows have been done
# ---
# 14000 rows have been done
# ---
# 409000 rows have been done
# ---
# 804000 rows have been done
# ---
# 656000 rows have been done
# ---
# 113000 rows have been done
# ---
# 261000 rows have been done
# ---
# 508000 rows have been done
# ---
# 903000 rows have been done
# ---
# 212000 rows have been done
# ---
# 360000 rows have been done
# ---
# 755000 rows have been done
# ---
# 607000 rows have been done
# ---
# 1002000 rows have been done
# ---
# 64000 rows have been done
# ---
# 459000 rows have been done
# ---
# 854000 rows have been done
# ---
# 163000 rows have been done
# ---
# 311000 rows have been done
# ---
# 706000 rows have been done
# ---
# 558000 rows have been done
# ---
# 953000 rows have been done
# ---
# 15000 rows have been done
# ---
# 410000 rows have been done
# ---
# 805000 rows have been done
# ---
# 657000 rows have been done
# ---
# 114000 rows have been done
# ---
# 262000 rows have been done
# ---
# 509000 rows have been done
# ---
# 904000 rows have been done
# ---
# 213000 rows have been done
# ---
# 361000 rows have been done
# ---
# 756000 rows have been done
# ---
# 608000 rows have been done
# ---
# 1003000 rows have been done
# ---
# 65000 rows have been done
# ---
# 460000 rows have been done
# ---
# 855000 rows have been done
# ---
# 164000 rows have been done
# ---
# 312000 rows have been done
# ---
# 707000 rows have been done
# ---
# 559000 rows have been done
# ---
# 954000 rows have been done
# ---
# 16000 rows have been done
# ---
# 411000 rows have been done
# ---
# 806000 rows have been done
# ---
# 658000 rows have been done
# ---
# 115000 rows have been done
# ---
# 510000 rows have been done
# ---
# 263000 rows have been done
# ---
# 905000 rows have been done
# ---
# 214000 rows have been done
# ---
# 362000 rows have been done
# ---
# 757000 rows have been done
# ---
# 609000 rows have been done
# ---
# 1004000 rows have been done
# ---
# 66000 rows have been done
# ---
# 461000 rows have been done
# ---
# 856000 rows have been done
# ---
# 165000 rows have been done
# ---
# 313000 rows have been done
# ---
# 708000 rows have been done
# ---
# 560000 rows have been done
# ---
# 955000 rows have been done
# ---
# 17000 rows have been done
# ---
# 412000 rows have been done
# ---
# 807000 rows have been done
# ---
# 659000 rows have been done
# ---
# 116000 rows have been done
# ---
# 511000 rows have been done
# ---
# 264000 rows have been done
# ---
# 906000 rows have been done
# ---
# 215000 rows have been done
# ---
# 363000 rows have been done
# ---
# 758000 rows have been done
# ---
# 610000 rows have been done
# ---
# 1005000 rows have been done
# ---
# 67000 rows have been done
# ---
# 462000 rows have been done
# ---
# 857000 rows have been done
# ---
# 166000 rows have been done
# ---
# 314000 rows have been done
# ---
# 709000 rows have been done
# ---
# 561000 rows have been done
# ---
# 956000 rows have been done
# ---
# 18000 rows have been done
# ---
# 413000 rows have been done
# ---
# 808000 rows have been done
# ---
# 117000 rows have been done
# ---
# 660000 rows have been done
# ---
# 512000 rows have been done
# ---
# 265000 rows have been done
# ---
# 907000 rows have been done
# ---
# 216000 rows have been done
# ---
# 364000 rows have been done
# ---
# 759000 rows have been done
# ---
# 611000 rows have been done
# ---
# 1006000 rows have been done
# ---
# 68000 rows have been done
# ---
# 463000 rows have been done
# ---
# 858000 rows have been done
# ---
# 167000 rows have been done
# ---
# 315000 rows have been done
# ---
# 710000 rows have been done
# ---
# 562000 rows have been done
# ---
# 957000 rows have been done
# ---
# 19000 rows have been done
# ---
# 414000 rows have been done
# ---
# 809000 rows have been done
# ---
# 661000 rows have been done
# ---
# 118000 rows have been done
# ---
# 513000 rows have been done
# ---
# 266000 rows have been done
# ---
# 908000 rows have been done
# ---
# 217000 rows have been done
# ---
# 365000 rows have been done
# ---
# 760000 rows have been done
# ---
# 612000 rows have been done
# ---
# 1007000 rows have been done
# ---
# 69000 rows have been done
# ---
# 464000 rows have been done
# ---
# 859000 rows have been done
# ---
# 168000 rows have been done
# ---
# 316000 rows have been done
# ---
# 711000 rows have been done
# ---
# 563000 rows have been done
# ---
# 958000 rows have been done
# ---
# 20000 rows have been done
# ---
# 415000 rows have been done
# ---
# 810000 rows have been done
# ---
# 119000 rows have been done
# ---
# 662000 rows have been done
# ---
# 514000 rows have been done
# ---
# 267000 rows have been done
# ---
# 909000 rows have been done
# ---
# 218000 rows have been done
# ---
# 366000 rows have been done
# ---
# 761000 rows have been done
# ---
# 613000 rows have been done1008000 rows have been done
# ---
#
# ---
# 70000 rows have been done
# ---
# 465000 rows have been done
# ---
# 169000 rows have been done
# ---
# 860000 rows have been done
# ---
# 317000 rows have been done
# ---
# 712000 rows have been done
# ---
# 564000 rows have been done
# ---
# 959000 rows have been done
# ---
# 21000 rows have been done
# ---
# 416000 rows have been done
# ---
# 811000 rows have been done
# ---
# 120000 rows have been done
# ---
# 663000 rows have been done
# ---
# 515000 rows have been done
# ---
# 268000 rows have been done
# ---
# 910000 rows have been done
# ---
# 219000 rows have been done
# ---
# 367000 rows have been done
# ---
# 762000 rows have been done
# ---
# 1009000 rows have been done
# ---
# 614000 rows have been done
# ---
# 71000 rows have been done
# ---
# 466000 rows have been done
# ---
# 170000 rows have been done
# ---
# 861000 rows have been done
# ---
# 318000 rows have been done
# ---
# 713000 rows have been done
# ---
# 565000 rows have been done
# ---
# 960000 rows have been done
# ---
# 22000 rows have been done
# ---
# 417000 rows have been done
# ---
# 812000 rows have been done
# ---
# 121000 rows have been done
# ---
# 664000 rows have been done
# ---
# 516000 rows have been done
# ---
# 269000 rows have been done
# ---
# 911000 rows have been done
# ---
# 220000 rows have been done
# ---
# 368000 rows have been done
# ---
# 763000 rows have been done
# ---
# 1010000 rows have been done
# ---
# 615000 rows have been done
# ---
# 72000 rows have been done
# ---
# 467000 rows have been done
# ---
# 171000 rows have been done
# ---
# 862000 rows have been done
# ---
# 319000 rows have been done
# ---
# 714000 rows have been done
# ---
# 566000 rows have been done
# ---
# 961000 rows have been done
# ---
# 23000 rows have been done
# ---
# 418000 rows have been done
# ---
# 813000 rows have been done
# ---
# 122000 rows have been done
# ---
# 665000 rows have been done
# ---
# 517000 rows have been done
# ---
# 270000 rows have been done
# ---
# 912000 rows have been done
# ---
# 221000 rows have been done
# ---
# 369000 rows have been done
# ---
# 764000 rows have been done
# ---
# 1011000 rows have been done
# ---
# 616000 rows have been done
# ---
# 73000 rows have been done
# ---
# 468000 rows have been done
# ---
# 172000 rows have been done
# ---
# 863000 rows have been done
# ---
# 320000 rows have been done
# ---
# 715000 rows have been done
# ---
# 567000 rows have been done
# ---
# 962000 rows have been done
# ---
# 24000 rows have been done
# ---
# 419000 rows have been done
# ---
# 814000 rows have been done
# ---
# 123000 rows have been done
# ---
# 666000 rows have been done
# ---
# 518000 rows have been done
# ---
# 271000 rows have been done
# ---
# 913000 rows have been done
# ---
# 222000 rows have been done
# ---
# 370000 rows have been done
# ---
# 765000 rows have been done
# ---
# 1012000 rows have been done
# ---
# 617000 rows have been done
# ---
# 74000 rows have been done
# ---
# 173000 rows have been done
# ---
# 469000 rows have been done
# ---
# 864000 rows have been done
# ---
# 321000 rows have been done
# ---
# 716000 rows have been done
# ---
# 568000 rows have been done
# ---
# 963000 rows have been done
# ---
# 25000 rows have been done
# ---
# 420000 rows have been done
# ---
# 815000 rows have been done
# ---
# 124000 rows have been done
# ---
# 667000 rows have been done
# ---
# 519000 rows have been done
# ---
# 272000 rows have been done
# ---
# 914000 rows have been done
# ---
# 223000 rows have been done
# ---
# 371000 rows have been done
# ---
# 766000 rows have been done
# ---
# 1013000 rows have been done
# ---
# 618000 rows have been done
# ---
# 75000 rows have been done
# ---
# 174000 rows have been done
# ---
# 470000 rows have been done
# ---
# 865000 rows have been done
# ---
# 322000 rows have been done
# ---
# 717000 rows have been done
# ---
# 569000 rows have been done
# ---
# 964000 rows have been done
# ---
# 26000 rows have been done
# ---
# 421000 rows have been done
# ---
# 816000 rows have been done
# ---
# 125000 rows have been done
# ---
# 668000 rows have been done
# ---
# 520000 rows have been done
# ---
# 273000 rows have been done
# ---
# 915000 rows have been done
# ---
# 224000 rows have been done
# ---
# 372000 rows have been done
# ---
# 767000 rows have been done
# ---
# 1014000 rows have been done
# ---
# 619000 rows have been done
# ---
# 76000 rows have been done
# ---
# 175000 rows have been done
# ---
# 471000 rows have been done
# ---
# 866000 rows have been done
# ---
# 323000 rows have been done
# ---
# 718000 rows have been done
# ---
# 570000 rows have been done
# ---
# 965000 rows have been done
# ---
# 27000 rows have been done
# ---
# 422000 rows have been done
# ---
# 817000 rows have been done
# ---
# 126000 rows have been done
# ---
# 669000 rows have been done
# ---
# 521000 rows have been done
# ---
# 274000 rows have been done
# ---
# 916000 rows have been done
# ---
# 225000 rows have been done
# ---
# 373000 rows have been done
# ---
# 768000 rows have been done
# ---
# 1015000 rows have been done
# ---
# 620000 rows have been done
# ---
# 77000 rows have been done
# ---
# 176000 rows have been done
# ---
# 472000 rows have been done
# ---
# 867000 rows have been done
# ---
# 324000 rows have been done
# ---
# 719000 rows have been done
# ---
# 571000 rows have been done
# ---
# 966000 rows have been done
# ---
# 28000 rows have been done
# ---
# 423000 rows have been done
# ---
# 818000 rows have been done
# ---
# 127000 rows have been done
# ---
# 670000 rows have been done
# ---
# 522000 rows have been done
# ---
# 275000 rows have been done
# ---
# 917000 rows have been done
# ---
# 226000 rows have been done
# ---
# 374000 rows have been done
# ---
# 769000 rows have been done
# ---
# 1016000 rows have been done
# ---
# 621000 rows have been done
# ---
# 78000 rows have been done
# ---
# 177000 rows have been done
# ---
# 473000 rows have been done
# ---
# 868000 rows have been done
# ---
# 720000 rows have been done
# ---
# 325000 rows have been done
# ---
# 572000 rows have been done
# ---
# 967000 rows have been done
# ---
# 29000 rows have been done
# ---
# 424000 rows have been done
# ---
# 819000 rows have been done
# ---
# 128000 rows have been done
# ---
# 671000 rows have been done
# ---
# 523000 rows have been done
# ---
# 276000 rows have been done
# ---
# 918000 rows have been done
# ---
# 227000 rows have been done
# ---
# 375000 rows have been done
# ---
# 770000 rows have been done
# ---
# 1017000 rows have been done
# ---
# 622000 rows have been done
# ---
# 79000 rows have been done
# ---
# 178000 rows have been done
# ---
# 474000 rows have been done
# ---
# 869000 rows have been done
# ---
# 721000 rows have been done
# ---
# 326000 rows have been done
# ---
# 573000 rows have been done
# ---
# 968000 rows have been done
# ---
# 30000 rows have been done
# ---
# 425000 rows have been done
# ---
# 820000 rows have been done
# ---
# 129000 rows have been done
# ---
# 672000 rows have been done
# ---
# 524000 rows have been done
# ---
# 277000 rows have been done
# ---
# 919000 rows have been done
# ---
# 228000 rows have been done
# ---
# 376000 rows have been done
# ---
# 771000 rows have been done
# ---
# 1018000 rows have been done
# ---
# 623000 rows have been done
# ---
# 80000 rows have been done
# ---
# 179000 rows have been done
# ---
# 475000 rows have been done
# ---
# 870000 rows have been done
# ---
# 722000 rows have been done
# ---
# 327000 rows have been done
# ---
# 574000 rows have been done
# ---
# 969000 rows have been done
# ---
# 31000 rows have been done
# ---
# 426000 rows have been done
# ---
# 821000 rows have been done
# ---
# 130000 rows have been done
# ---
# 673000 rows have been done
# ---
# 525000 rows have been done
# ---
# 278000 rows have been done
# ---
# 920000 rows have been done
# ---
# 229000 rows have been done
# ---
# 377000 rows have been done
# ---
# 772000 rows have been done
# ---
# 1019000 rows have been done
# ---
# 624000 rows have been done
# ---
# 81000 rows have been done
# ---
# 180000 rows have been done
# ---
# 476000 rows have been done
# ---
# 871000 rows have been done
# ---
# 723000 rows have been done
# ---
# 328000 rows have been done
# ---
# 575000 rows have been done
# ---
# 970000 rows have been done
# ---
# 32000 rows have been done
# ---
# 427000 rows have been done
# ---
# 822000 rows have been done
# ---
# 131000 rows have been done
# ---
# 674000 rows have been done
# ---
# 526000 rows have been done
# ---
# 279000 rows have been done
# ---
# 921000 rows have been done
# ---
# 230000 rows have been done
# ---
# 378000 rows have been done
# ---
# 773000 rows have been done
# ---
# 625000 rows have been done
# ---
# 1020000 rows have been done
# ---
# 82000 rows have been done
# ---
# 181000 rows have been done
# ---
# 477000 rows have been done
# ---
# 872000 rows have been done
# ---
# 724000 rows have been done
# ---
# 329000 rows have been done
# ---
# 576000 rows have been done
# ---
# 971000 rows have been done
# ---
# 33000 rows have been done
# ---
# 428000 rows have been done
# ---
# 823000 rows have been done
# ---
# 132000 rows have been done
# ---
# 675000 rows have been done
# ---
# 527000 rows have been done
# ---
# 280000 rows have been done
# ---
# 922000 rows have been done
# ---
# 231000 rows have been done
# ---
# 379000 rows have been done
# ---
# 774000 rows have been done
# ---
# 1021000 rows have been done
# ---
# 626000 rows have been done
# ---
# 83000 rows have been done
# ---
# 182000 rows have been done
# ---
# 478000 rows have been done
# ---
# 873000 rows have been done
# ---
# 725000 rows have been done
# ---
# 330000 rows have been done
# ---
# 577000 rows have been done
# ---
# 972000 rows have been done
# ---
# 34000 rows have been done
# ---
# 429000 rows have been done
# ---
# 824000 rows have been done
# ---
# 133000 rows have been done
# ---
# 676000 rows have been done
# ---
# 528000 rows have been done
# ---
# 281000 rows have been done
# ---
# 923000 rows have been done
# ---
# 232000 rows have been done
# ---
# 380000 rows have been done
# ---
# 775000 rows have been done
# ---
# 1022000 rows have been done
# ---
# 627000 rows have been done
# ---
# 84000 rows have been done
# ---
# 183000 rows have been done
# ---
# 479000 rows have been done
# ---
# 874000 rows have been done
# ---
# 726000 rows have been done
# ---
# 331000 rows have been done
# ---
# 578000 rows have been done
# ---
# 973000 rows have been done
# ---
# 35000 rows have been done
# ---
# 430000 rows have been done
# ---
# 825000 rows have been done
# ---
# 134000 rows have been done
# ---
# 677000 rows have been done
# ---
# 529000 rows have been done
# ---
# 282000 rows have been done
# ---
# 924000 rows have been done
# ---
# 233000 rows have been done
# ---
# 381000 rows have been done
# ---
# 776000 rows have been done
# ---
# 1023000 rows have been done
# ---
# 628000 rows have been done
# ---
# 85000 rows have been done
# ---
# 184000 rows have been done
# ---
# 480000 rows have been done
# ---
# 875000 rows have been done
# ---
# 727000 rows have been done
# ---
# 332000 rows have been done
# ---
# 579000 rows have been done
# ---
# 974000 rows have been done
# ---
# 36000 rows have been done
# ---
# 431000 rows have been done
# ---
# 826000 rows have been done
# ---
# 135000 rows have been done
# ---
# 678000 rows have been done
# ---
# 530000 rows have been done
# ---
# 283000 rows have been done
# ---
# 925000 rows have been done
# ---
# 234000 rows have been done
# ---
# 382000 rows have been done
# ---
# 777000 rows have been done
# ---
# 1024000 rows have been done
# ---
# 629000 rows have been done
# ---
# 86000 rows have been done
# ---
# 185000 rows have been done
# ---
# 481000 rows have been done
# ---
# 876000 rows have been done
# ---
# 728000 rows have been done
# ---
# 333000 rows have been done
# ---
# 580000 rows have been done
# ---
# 975000 rows have been done
# ---
# 37000 rows have been done
# ---
# 432000 rows have been done
# ---
# 827000 rows have been done
# ---
# 136000 rows have been done
# ---
# 679000 rows have been done
# ---
# 531000 rows have been done
# ---
# 284000 rows have been done
# ---
# 926000 rows have been done
# ---
# 235000 rows have been done
# ---
# 383000 rows have been done
# ---
# 778000 rows have been done
# ---
# 1025000 rows have been done
# ---
# 630000 rows have been done
# ---
# 87000 rows have been done
# ---
# 186000 rows have been done
# ---
# 482000 rows have been done
# ---
# 877000 rows have been done
# ---
# 729000 rows have been done
# ---
# 334000 rows have been done
# ---
# 581000 rows have been done
# ---
# 976000 rows have been done
# ---
# 38000 rows have been done
# ---
# 433000 rows have been done
# ---
# 137000 rows have been done
# ---
# 828000 rows have been done
# ---
# 680000 rows have been done
# ---
# 532000 rows have been done
# ---
# 285000 rows have been done
# ---
# 927000 rows have been done
# ---
# 236000 rows have been done
# ---
# 384000 rows have been done
# ---
# 779000 rows have been done
# ---
# 1026000 rows have been done
# ---
# 631000 rows have been done
# ---
# 88000 rows have been done
# ---
# 187000 rows have been done
# ---
# 483000 rows have been done
# ---
# 878000 rows have been done
# ---
# 730000 rows have been done
# ---
# 335000 rows have been done
# ---
# 582000 rows have been done
# ---
# 977000 rows have been done
# ---
# 39000 rows have been done
# ---
# 434000 rows have been done
# ---
# 138000 rows have been done
# ---
# 829000 rows have been done
# ---
# 681000 rows have been done
# ---
# 533000 rows have been done
# ---
# 286000 rows have been done
# ---
# 928000 rows have been done
# ---
# 237000 rows have been done
# ---
# 385000 rows have been done
# ---
# 780000 rows have been done
# ---
# 1027000 rows have been done
# ---
# 632000 rows have been done
# ---
# 89000 rows have been done
# ---
# 188000 rows have been done
# ---
# 484000 rows have been done
# ---
# 879000 rows have been done
# ---
# 731000 rows have been done
# ---
# 336000 rows have been done
# ---
# 583000 rows have been done
# ---
# 978000 rows have been done
# ---
# 40000 rows have been done
# ---
# 435000 rows have been done
# ---
# 139000 rows have been done
# ---
# 830000 rows have been done
# ---
# 682000 rows have been done
# ---
# 534000 rows have been done
# ---
# 287000 rows have been done
# ---
# 929000 rows have been done
# ---
# 238000 rows have been done
# ---
# 781000 rows have been done
# ---
# 386000 rows have been done
# ---
# 1028000 rows have been done
# ---
# 633000 rows have been done
# ---
# 90000 rows have been done
# ---
# 189000 rows have been done
# ---
# 485000 rows have been done
# ---
# 880000 rows have been done
# ---
# 732000 rows have been done
# ---
# 337000 rows have been done
# ---
# 584000 rows have been done
# ---
# 979000 rows have been done
# ---
# 41000 rows have been done
# ---
# 436000 rows have been done
# ---
# 140000 rows have been done
# ---
# 831000 rows have been done
# ---
# 683000 rows have been done
# ---
# 535000 rows have been done
# ---
# 288000 rows have been done
# ---
# 930000 rows have been done
# ---
# 239000 rows have been done
# ---
# 782000 rows have been done
# ---
# 387000 rows have been done
# ---
# 1029000 rows have been done
# ---
# 634000 rows have been done
# ---
# 91000 rows have been done
# ---
# 190000 rows have been done
# ---
# 486000 rows have been done
# ---
# 881000 rows have been done
# ---
# 733000 rows have been done
# ---
# 338000 rows have been done
# ---
# 585000 rows have been done
# ---
# 980000 rows have been done
# ---
# 42000 rows have been done
# ---
# 437000 rows have been done
# ---
# 141000 rows have been done
# ---
# 832000 rows have been done
# ---
# 684000 rows have been done
# ---
# 536000 rows have been done
# ---
# 289000 rows have been done
# ---
# 931000 rows have been done
# ---
# 240000 rows have been done
# ---
# 783000 rows have been done
# ---
# 388000 rows have been done
# ---
# 1030000 rows have been done
# ---
# 635000 rows have been done
# ---
# 92000 rows have been done
# ---
# 191000 rows have been done
# ---
# 487000 rows have been done
# ---
# 882000 rows have been done
# ---
# 734000 rows have been done
# ---
# 339000 rows have been done
# ---
# 586000 rows have been done
# ---
# 981000 rows have been done
# ---
# 43000 rows have been done
# ---
# 438000 rows have been done
# ---
# 142000 rows have been done
# ---
# 833000 rows have been done
# ---
# 685000 rows have been done
# ---
# 537000 rows have been done
# ---
# 290000 rows have been done
# ---
# 932000 rows have been done
# ---
# 241000 rows have been done
# ---
# 784000 rows have been done
# ---
# 389000 rows have been done
# ---
# 1031000 rows have been done
# ---
# 636000 rows have been done
# ---
# 93000 rows have been done
# ---
# 192000 rows have been done
# ---
# 488000 rows have been done
# ---
# 883000 rows have been done
# ---
# 735000 rows have been done
# ---
# 340000 rows have been done
# ---
# 587000 rows have been done
# ---
# 982000 rows have been done
# ---
# 44000 rows have been done
# ---
# 439000 rows have been done
# ---
# 143000 rows have been done
# ---
# 834000 rows have been done
# ---
# 686000 rows have been done
# ---
# 538000 rows have been done
# ---
# 291000 rows have been done
# ---
# 933000 rows have been done
# ---
# 242000 rows have been done
# ---
# 785000 rows have been done
# ---
# 390000 rows have been done
# ---
# 1032000 rows have been done
# ---
# 637000 rows have been done
# ---
# 94000 rows have been done
# ---
# 193000 rows have been done
# ---
# 489000 rows have been done
# ---
# 884000 rows have been done
# ---
# 736000 rows have been done
# ---
# 341000 rows have been done
# ---
# 588000 rows have been done
# ---
# 983000 rows have been done
# ---
# 45000 rows have been done
# ---
# 440000 rows have been done
# ---
# 144000 rows have been done
# ---
# 835000 rows have been done
# ---
# 687000 rows have been done
# ---
# 539000 rows have been done
# ---
# 292000 rows have been done
# ---
# 934000 rows have been done
# ---
# 243000 rows have been done
# ---
# 786000 rows have been done
# ---
# 391000 rows have been done
# ---
# 638000 rows have been done
# ---
# 1033000 rows have been done
# ---
# 95000 rows have been done
# ---
# 194000 rows have been done
# ---
# 490000 rows have been done
# ---
# 885000 rows have been done
# ---
# 737000 rows have been done
# ---
# 342000 rows have been done
# ---
# 589000 rows have been done
# ---
# 984000 rows have been done
# ---
# 46000 rows have been done
# ---
# 145000 rows have been done
# ---
# 441000 rows have been done
# ---
# 836000 rows have been done
# ---
# 688000 rows have been done
# ---
# 540000 rows have been done
# ---
# 293000 rows have been done
# ---
# 935000 rows have been done
# ---
# 244000 rows have been done
# ---
# 787000 rows have been done
# ---
# 392000 rows have been done
# ---
# 639000 rows have been done
# ---
# 1034000 rows have been done
# ---
# 96000 rows have been done
# ---
# 195000 rows have been done
# ---
# 491000 rows have been done
# ---
# 886000 rows have been done
# ---
# 738000 rows have been done
# ---
# 343000 rows have been done
# ---
# 590000 rows have been done
# ---
# 985000 rows have been done
# ---
# 47000 rows have been done
# ---
# 146000 rows have been done
# ---
# 442000 rows have been done
# ---
# 837000 rows have been done
# ---
# 689000 rows have been done
# ---
# 541000 rows have been done
# ---
# 294000 rows have been done
# ---
# 936000 rows have been done
# ---
# 245000 rows have been done
# ---
# 788000 rows have been done
# ---
# 393000 rows have been done
# ---
# 640000 rows have been done
# ---
# 1035000 rows have been done
# ---
# 97000 rows have been done
# ---
# 196000 rows have been done
# ---
# 492000 rows have been done
# ---
# 887000 rows have been done
# ---
# 739000 rows have been done
# ---
# 344000 rows have been done
# ---
# 591000 rows have been done
# ---
# 986000 rows have been done
# ---
# 48000 rows have been done
# ---
# 147000 rows have been done
# ---
# 443000 rows have been done
# ---
# 838000 rows have been done
# ---
# 690000 rows have been done
# ---
# 542000 rows have been done
# ---
# 295000 rows have been done
# ---
# 937000 rows have been done
# ---
# 246000 rows have been done
# ---
# 789000 rows have been done
# ---
# 394000 rows have been done
# ---
# 641000 rows have been done
# ---
# 1036000 rows have been done
# ---
# 98000 rows have been done
# ---
# 197000 rows have been done
# ---
# 493000 rows have been done
# ---
# 888000 rows have been done
# ---
# 740000 rows have been done
# ---
# 345000 rows have been done
# ---
# 592000 rows have been done
# ---
# 987000 rows have been done
# ---
# 49000 rows have been done
# ---
# 148000 rows have been done
# ---
# 444000 rows have been done
# ---
# 839000 rows have been done
# ---
# 691000 rows have been done
# ---
# 543000 rows have been done
# ---
# 296000 rows have been done
# ---
# 938000 rows have been done
# ---
# 790000 rows have been done
# ---
# 395000 rows have been done
# ---
# 1037000 rows have been done
# ---
# All threads have finished processing.
#
# Before selected by Rule, number of news is: 1037035
# After selected by Rule, number of news is: 475242
# Droped by Rule, number of news is: 561372

# %%
# Save the filtered data to new Excel files
result_df.to_excel("News_output\\News_training_domain_set_withoutCompany.xlsx", index=False)
drop_df.to_excel("News_input\\News_2nd_filting_set.xlsx", index=False)

# %% [markdown]
# ### 1.3. Apply explicit_company to each news inTraining domain set

# %%
from concurrent.futures import ThreadPoolExecutor
import pandas as pd
import threading
import json
import jieba
import re

# Define Trie dictionary tree node
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end_of_word = False
        self.company_name = None  # Store the company name

# Create a Trie dictionary tree
def build_trie(company_list):
    root = TrieNode()
    for company in company_list:
        node = root
        name = company["name"]
        for char in name:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]
        node.is_end_of_word = True
        node.company_name = name  # Store the company name
    return root

# Function to extract companies from text
def extract_companies_from_text(text, trie_root):
    companies = set()

    def search_trie(text, node):
        for i in range(len(text)):
            char = text[i]
            if char in node.children:
                node = node.children[char]
                if node.is_end_of_word:
                    companies.add(node.company_name)
            else:
                break

    for i in range(len(text)):
        search_trie(text[i:], trie_root)

    return companies

# %%
# Read the JSON file containing company information
with open("News_input\\A_share_list\\new_A_share_list.json", "r", encoding="utf-8") as file:
    a_share_list = json.load(file)

# Build a trie (prefix tree) using the data from the JSON file (assuming 'build_trie()' function is defined elsewhere)
a_share_trie = build_trie(a_share_list)

# %%
# Updated extraction_row function
def extraction_row(row, trie_root):
    title = row["Title"]
    news_content = row["NewsContent"]
    news = title + news_content

    matched_company_names = extract_companies_from_text(news, trie_root)

    # Convert the matched company names set to a comma-separated string
    matched_company_names_str = ", ".join(matched_company_names)

    return {
        "NewsID": row["NewsID"],
        "Title": title,
        "NewsContent": news_content,
        "NewsSource": row["NewsSource"],
        "Explicit_Company": matched_company_names_str  # Extracted matched company names
    }

# Main processing function
def extraction_data(start, end, full_data, trie_root, extraction_list):
    for i in range(start, end):
        if i % 100 == 0:
            print("--- {} rows have been done ---".format(i))
        combined_row = extraction_row(full_data.iloc[i], trie_root)
        with lock:
            extraction_list.append(combined_row)

# %%
withoutCompany_df = pd.read_excel("News_output\\News_training_domain_set_withoutCompany.xlsx")

# %%
# Create a global lock to ensure thread safety
lock = threading.Lock()

# Split data into chunks
num_threads = 20  # Specify the number of threads
chunk_size = len(withoutCompany_df) // num_threads

threads = []
extraction_list = []
print("Processing data with {} threads...".format(num_threads))

for i in range(num_threads):
    start = i * chunk_size
    end = (i + 1) * chunk_size if i < num_threads - 1 else len(withoutCompany_df)
    thread = threading.Thread(target=extraction_data, args=(start, end, withoutCompany_df, a_share_trie, extraction_list))
    threads.append(thread)
    print("Thread {} is processing rows {} to {}...".format(i + 1, start, end))
    
for thread in threads:
    thread.start()

for thread in threads:
    thread.join()

print("All threads have finished processing.\n")

# Merge the results
extraction_df = pd.concat([pd.DataFrame(extraction_list)])
# Out:
# Processing data with 20 threads...
# Thread 1 is processing rows 0 to 23762...
# Thread 2 is processing rows 23762 to 47524...
# Thread 3 is processing rows 47524 to 71286...
# Thread 4 is processing rows 71286 to 95048...
# Thread 5 is processing rows 95048 to 118810...
# Thread 6 is processing rows 118810 to 142572...
# Thread 7 is processing rows 142572 to 166334...
# Thread 8 is processing rows 166334 to 190096...
# Thread 9 is processing rows 190096 to 213858...
# Thread 10 is processing rows 213858 to 237620...
# Thread 11 is processing rows 237620 to 261382...
# Thread 12 is processing rows 261382 to 285144...
# Thread 13 is processing rows 285144 to 308906...
# Thread 14 is processing rows 308906 to 332668...
# Thread 15 is processing rows 332668 to 356430...
# Thread 16 is processing rows 356430 to 380192...
# Thread 17 is processing rows 380192 to 403954...
# Thread 18 is processing rows 403954 to 427716...
# Thread 19 is processing rows 427716 to 451478...
# Thread 20 is processing rows 451478 to 475242...
# --- 0 rows have been done ---
# --- 23800 rows have been done ---
# --- 100 rows have been done ---
# --- 71300 rows have been done ---
# --- 47600 rows have been done ------ 95100 rows have been done ---
#
# --- 200 rows have been done ---
# --- 23900 rows have been done ---
# --- 71400 rows have been done ---
# --- 142600 rows have been done ---
# --- 47700 rows have been done ---
# --- 24000 rows have been done ---
# --- 142700 rows have been done ------ 95200 rows have been done ---
#
# --- 166400 rows have been done ---
# --- 47800 rows have been done ---
# --- 118900 rows have been done ---
# --- 190100 rows have been done ---
# --- 24100 rows have been done ---
# --- 300 rows have been done ---
# --- 47900 rows have been done ---
# --- 166500 rows have been done ---
# --- 48000 rows have been done ---
# --- 261400 rows have been done ---
# --- 119000 rows have been done ---
# --- 71500 rows have been done ---
# --- 380200 rows have been done ---
# --- 237700 rows have been done ---
# --- 213900 rows have been done ---
# --- 451500 rows have been done ---
# --- 142800 rows have been done ---
# --- 95300 rows have been done ---
# --- 332700 rows have been done ---
# --- 190200 rows have been done ---
# --- 166600 rows have been done ---
# --- 404000 rows have been done ---
# --- 285200 rows have been done ---
# --- 48100 rows have been done ---
# --- 400 rows have been done ---
# --- 356500 rows have been done ---
# --- 24200 rows have been done ---
# --- 427800 rows have been done ---
# --- 119100 rows have been done ---
# --- 261500 rows have been done ---
# --- 309000 rows have been done ---
# --- 71600 rows have been done ---
# --- 380300 rows have been done ---
# --- 237800 rows have been done ---
# --- 214000 rows have been done ---
# --- 451600 rows have been done ---
# --- 142900 rows have been done ---
# --- 95400 rows have been done ---
# --- 332800 rows have been done ---
# --- 190300 rows have been done ---
# --- 166700 rows have been done ---
# --- 404100 rows have been done ---
# --- 285300 rows have been done ---
# --- 48200 rows have been done ---
# --- 500 rows have been done ---
# --- 356600 rows have been done ---
# --- 24300 rows have been done ---
# --- 427900 rows have been done ---
# --- 119200 rows have been done ---
# --- 261600 rows have been done ---
# --- 309100 rows have been done ---
# --- 71700 rows have been done ---
# --- 380400 rows have been done ---
# --- 237900 rows have been done ---
# --- 214100 rows have been done ---
# --- 451700 rows have been done ---
# --- 143000 rows have been done ---
# --- 95500 rows have been done ---
# --- 332900 rows have been done ---
# --- 190400 rows have been done ---
# --- 166800 rows have been done ---
# --- 404200 rows have been done ---
# --- 285400 rows have been done ---
# --- 48300 rows have been done ---
# --- 600 rows have been done ---
# --- 356700 rows have been done ---
# --- 24400 rows have been done ---
# --- 428000 rows have been done ---
# --- 119300 rows have been done ---
# --- 261700 rows have been done ---
# --- 309200 rows have been done ---
# --- 71800 rows have been done ---
# --- 380500 rows have been done ---
# --- 238000 rows have been done ---
# --- 214200 rows have been done ---
# --- 451800 rows have been done ---
# --- 143100 rows have been done ---
# --- 95600 rows have been done ---
# --- 333000 rows have been done ---
# --- 190500 rows have been done ---
# --- 166900 rows have been done ---
# --- 404300 rows have been done ---
# --- 285500 rows have been done ---
# --- 48400 rows have been done ---
# --- 700 rows have been done ---
# --- 356800 rows have been done ---
# --- 24500 rows have been done ---
# --- 428100 rows have been done ---
# --- 119400 rows have been done ---
# --- 261800 rows have been done ---
# --- 309300 rows have been done ---
# --- 71900 rows have been done ---
# --- 380600 rows have been done ---
# --- 238100 rows have been done ---
# --- 214300 rows have been done ---
# --- 451900 rows have been done ---
# --- 143200 rows have been done ---
# --- 95700 rows have been done ---
# --- 333100 rows have been done ---
# --- 190600 rows have been done ---
# --- 167000 rows have been done ---
# --- 404400 rows have been done ---
# --- 285600 rows have been done ---
# --- 48500 rows have been done ---
# --- 800 rows have been done ---
# --- 356900 rows have been done ---
# --- 24600 rows have been done ---
# --- 428200 rows have been done ---
# --- 119500 rows have been done ---
# --- 261900 rows have been done ---
# --- 309400 rows have been done ---
# --- 72000 rows have been done ---
# --- 380700 rows have been done ---
# --- 238200 rows have been done ------ 214400 rows have been done ---
#
# --- 452000 rows have been done ---
# --- 143300 rows have been done ---
# --- 95800 rows have been done ---
# --- 333200 rows have been done ---
# --- 190700 rows have been done ---
# --- 167100 rows have been done ---
# --- 404500 rows have been done ---
# --- 285700 rows have been done ---
# --- 48600 rows have been done ---
# --- 900 rows have been done ---
# --- 357000 rows have been done ---
# --- 24700 rows have been done ---
# --- 428300 rows have been done ---
# --- 119600 rows have been done ---
# --- 262000 rows have been done ---
# --- 309500 rows have been done ---
# --- 72100 rows have been done ---
# --- 380800 rows have been done ---
# --- 214500 rows have been done ---
# --- 238300 rows have been done ---
# --- 452100 rows have been done ---
# --- 143400 rows have been done ---
# --- 95900 rows have been done ---
# --- 333300 rows have been done ---
# --- 190800 rows have been done ---
# --- 167200 rows have been done ---
# --- 404600 rows have been done ---
# --- 285800 rows have been done ---
# --- 48700 rows have been done ---
# --- 1000 rows have been done ---
# --- 357100 rows have been done ---
# --- 24800 rows have been done ---
# --- 428400 rows have been done ---
# --- 119700 rows have been done ---
# --- 262100 rows have been done ---
# --- 309600 rows have been done ---
# --- 72200 rows have been done ---
# --- 380900 rows have been done ---
# --- 214600 rows have been done ------ 238400 rows have been done ---
#
# --- 452200 rows have been done ---
# --- 143500 rows have been done ---
# --- 96000 rows have been done ---
# --- 333400 rows have been done ---
# --- 190900 rows have been done ---
# --- 167300 rows have been done ---
# --- 404700 rows have been done ---
# --- 285900 rows have been done ---
# --- 48800 rows have been done ---
# --- 1100 rows have been done ---
# --- 357200 rows have been done ---
# --- 24900 rows have been done ---
# --- 428500 rows have been done ---
# --- 119800 rows have been done ---
# --- 262200 rows have been done ---
# --- 309700 rows have been done ---
# --- 72300 rows have been done ---
# --- 381000 rows have been done ---
# --- 238500 rows have been done ---
# --- 214700 rows have been done ---
# --- 452300 rows have been done ---
# --- 143600 rows have been done ---
# --- 96100 rows have been done ---
# --- 333500 rows have been done ---
# --- 191000 rows have been done ---
# --- 167400 rows have been done ---
# --- 404800 rows have been done ---
# --- 286000 rows have been done ---
# --- 48900 rows have been done ---
# --- 1200 rows have been done ---
# --- 357300 rows have been done ---
# --- 25000 rows have been done ---
# --- 428600 rows have been done ---
# --- 119900 rows have been done ---
# --- 262300 rows have been done ---
# --- 309800 rows have been done ---
# --- 72400 rows have been done ---
# --- 381100 rows have been done ---
# --- 238600 rows have been done ------ 214800 rows have been done ---
#
# --- 452400 rows have been done ---
# --- 143700 rows have been done ---
# --- 96200 rows have been done ---
# --- 333600 rows have been done ---
# --- 191100 rows have been done ---
# --- 167500 rows have been done ---
# --- 404900 rows have been done ---
# --- 286100 rows have been done ---
# --- 49000 rows have been done ---
# --- 1300 rows have been done ---
# --- 357400 rows have been done ---
# --- 25100 rows have been done ---
# --- 428700 rows have been done ---
# --- 120000 rows have been done ---
# --- 262400 rows have been done ---
# --- 309900 rows have been done ---
# --- 72500 rows have been done ---
# --- 381200 rows have been done ---
# --- 214900 rows have been done ------ 238700 rows have been done ---
#
# --- 452500 rows have been done ---
# --- 143800 rows have been done ---
# --- 96300 rows have been done ---
# --- 333700 rows have been done ---
# --- 191200 rows have been done ---
# --- 167600 rows have been done ---
# --- 405000 rows have been done ---
# --- 286200 rows have been done ---
# --- 49100 rows have been done ---
# --- 1400 rows have been done ---
# --- 357500 rows have been done ---
# --- 25200 rows have been done ---
# --- 428800 rows have been done ---
# --- 120100 rows have been done ---
# --- 262500 rows have been done ---
# --- 310000 rows have been done ---
# --- 72600 rows have been done ---
# --- 381300 rows have been done ---
# --- 238800 rows have been done ---
# --- 215000 rows have been done ---
# --- 452600 rows have been done ---
# --- 143900 rows have been done ---
# --- 96400 rows have been done ---
# --- 333800 rows have been done ---
# --- 191300 rows have been done ---
# --- 167700 rows have been done ---
# --- 405100 rows have been done ---
# --- 286300 rows have been done ---
# --- 49200 rows have been done ---
# --- 1500 rows have been done ---
# --- 357600 rows have been done ---
# --- 25300 rows have been done ---
# --- 428900 rows have been done ---
# --- 120200 rows have been done ---
# --- 262600 rows have been done ---
# --- 310100 rows have been done ---
# --- 72700 rows have been done ---
# --- 381400 rows have been done ---
# --- 238900 rows have been done ---
# --- 215100 rows have been done ---
# --- 452700 rows have been done ---
# --- 144000 rows have been done ---
# --- 96500 rows have been done ---
# --- 333900 rows have been done ---
# --- 191400 rows have been done ---
# --- 167800 rows have been done ---
# --- 405200 rows have been done ---
# --- 286400 rows have been done ---
# --- 49300 rows have been done ---
# --- 1600 rows have been done ---
# --- 357700 rows have been done ---
# --- 25400 rows have been done ---
# --- 429000 rows have been done ---
# --- 120300 rows have been done ---
# --- 262700 rows have been done ---
# --- 310200 rows have been done ---
# --- 72800 rows have been done ---
# --- 381500 rows have been done ---
# --- 239000 rows have been done ------ 215200 rows have been done ---
#
# --- 452800 rows have been done ---
# --- 144100 rows have been done ---
# --- 96600 rows have been done ---
# --- 334000 rows have been done ---
# --- 191500 rows have been done ---
# --- 167900 rows have been done ---
# --- 405300 rows have been done ---
# --- 286500 rows have been done ---
# --- 49400 rows have been done ------ 1700 rows have been done ---
#
# --- 357800 rows have been done ---
# --- 25500 rows have been done ---
# --- 429100 rows have been done ---
# --- 120400 rows have been done ---
# --- 262800 rows have been done ---
# --- 310300 rows have been done ---
# --- 72900 rows have been done ---
# --- 381600 rows have been done ---
# --- 215300 rows have been done ------ 239100 rows have been done ---
#
# --- 452900 rows have been done ---
# --- 144200 rows have been done ---
# --- 96700 rows have been done ---
# --- 334100 rows have been done ---
# --- 191600 rows have been done ---
# --- 168000 rows have been done ---
# --- 405400 rows have been done ---
# --- 286600 rows have been done ---
# --- 1800 rows have been done ---
# --- 49500 rows have been done ---
# --- 357900 rows have been done ---
# --- 25600 rows have been done ---
# --- 429200 rows have been done ---
# --- 120500 rows have been done ---
# --- 262900 rows have been done ---
# --- 310400 rows have been done ---
# --- 73000 rows have been done ---
# --- 381700 rows have been done ---
# --- 239200 rows have been done ---
# --- 215400 rows have been done ---
# --- 453000 rows have been done ---
# --- 144300 rows have been done ---
# --- 96800 rows have been done ---
# --- 334200 rows have been done ---
# --- 191700 rows have been done ---
# --- 168100 rows have been done ---
# --- 405500 rows have been done ---
# --- 286700 rows have been done ---
# --- 1900 rows have been done ---
# --- 49600 rows have been done ---
# --- 358000 rows have been done ---
# --- 25700 rows have been done ---
# --- 429300 rows have been done ---
# --- 120600 rows have been done ---
# --- 263000 rows have been done ---
# --- 310500 rows have been done ---
# --- 73100 rows have been done ---
# --- 381800 rows have been done ---
# --- 239300 rows have been done ------ 215500 rows have been done ---
#
# --- 453100 rows have been done ---
# --- 144400 rows have been done ---
# --- 96900 rows have been done ---
# --- 334300 rows have been done ---
# --- 191800 rows have been done ---
# --- 168200 rows have been done ---
# --- 405600 rows have been done ---
# --- 286800 rows have been done ---
# --- 2000 rows have been done ---
# --- 49700 rows have been done ---
# --- 358100 rows have been done ---
# --- 25800 rows have been done ---
# --- 429400 rows have been done ---
# --- 120700 rows have been done ---
# --- 263100 rows have been done ---
# --- 310600 rows have been done ---
# --- 73200 rows have been done ---
# --- 381900 rows have been done ---
# --- 215600 rows have been done ------ 239400 rows have been done ---
#
# --- 453200 rows have been done ---
# --- 144500 rows have been done ---
# --- 97000 rows have been done ---
# --- 334400 rows have been done ---
# --- 191900 rows have been done ---
# --- 168300 rows have been done ---
# --- 405700 rows have been done ---
# --- 286900 rows have been done ---
# --- 2100 rows have been done ---
# --- 49800 rows have been done ---
# --- 358200 rows have been done ---
# --- 25900 rows have been done ---
# --- 429500 rows have been done ---
# --- 120800 rows have been done ---
# --- 263200 rows have been done ---
# --- 310700 rows have been done ---
# --- 73300 rows have been done ---
# --- 382000 rows have been done ---
# --- 239500 rows have been done ------ 215700 rows have been done ---
#
# --- 453300 rows have been done ---
# --- 144600 rows have been done ---
# --- 97100 rows have been done ---
# --- 334500 rows have been done ---
# --- 192000 rows have been done ---
# --- 168400 rows have been done ---
# --- 405800 rows have been done ---
# --- 287000 rows have been done ---
# --- 2200 rows have been done ---
# --- 49900 rows have been done ---
# --- 358300 rows have been done ---
# --- 26000 rows have been done ---
# --- 429600 rows have been done ---
# --- 120900 rows have been done ---
# --- 263300 rows have been done ---
# --- 310800 rows have been done ---
# --- 73400 rows have been done ---
# --- 382100 rows have been done ---
# --- 215800 rows have been done ---
# --- 239600 rows have been done ---
# --- 453400 rows have been done ---
# --- 144700 rows have been done ---
# --- 97200 rows have been done ---
# --- 334600 rows have been done ---
# --- 192100 rows have been done ---
# --- 168500 rows have been done ---
# --- 405900 rows have been done ---
# --- 287100 rows have been done ---
# --- 2300 rows have been done ---
# --- 50000 rows have been done ---
# --- 358400 rows have been done ---
# --- 26100 rows have been done ---
# --- 429700 rows have been done ---
# --- 121000 rows have been done ---
# --- 263400 rows have been done ---
# --- 310900 rows have been done ---
# --- 73500 rows have been done ---
# --- 382200 rows have been done ---
# --- 215900 rows have been done ------ 239700 rows have been done ---
#
# --- 453500 rows have been done ---
# --- 144800 rows have been done ---
# --- 97300 rows have been done ---
# --- 334700 rows have been done ---
# --- 192200 rows have been done ---
# --- 168600 rows have been done ---
# --- 406000 rows have been done ---
# --- 287200 rows have been done ---
# --- 2400 rows have been done ---
# --- 50100 rows have been done ---
# --- 358500 rows have been done ---
# --- 26200 rows have been done ------ 429800 rows have been done ---
#
# --- 121100 rows have been done ---
# --- 263500 rows have been done ---
# --- 311000 rows have been done ---
# --- 73600 rows have been done ---
# --- 382300 rows have been done ---
# --- 239800 rows have been done ---
# --- 216000 rows have been done ---
# --- 453600 rows have been done ---
# --- 144900 rows have been done ---
# --- 97400 rows have been done ---
# --- 334800 rows have been done ---
# --- 192300 rows have been done ---
# --- 168700 rows have been done ---
# --- 406100 rows have been done ---
# --- 287300 rows have been done ---
# --- 2500 rows have been done ---
# --- 50200 rows have been done ---
# --- 358600 rows have been done ---
# --- 429900 rows have been done ---
# --- 26300 rows have been done ---
# --- 121200 rows have been done ---
# --- 263600 rows have been done ---
# --- 311100 rows have been done ---
# --- 73700 rows have been done ---
# --- 382400 rows have been done ---
# --- 239900 rows have been done ---
# --- 216100 rows have been done ---
# --- 453700 rows have been done ---
# --- 145000 rows have been done ---
# --- 97500 rows have been done ---
# --- 334900 rows have been done ---
# --- 192400 rows have been done ---
# --- 168800 rows have been done ---
# --- 406200 rows have been done ---
# --- 287400 rows have been done ---
# --- 2600 rows have been done ---
# --- 50300 rows have been done ---
# --- 358700 rows have been done ---
# --- 430000 rows have been done ---
# --- 26400 rows have been done ---
# --- 121300 rows have been done ---
# --- 263700 rows have been done ---
# --- 311200 rows have been done ---
# --- 73800 rows have been done ---
# --- 382500 rows have been done ---
# --- 240000 rows have been done ------ 216200 rows have been done ---
#
# --- 453800 rows have been done ---
# --- 145100 rows have been done ---
# --- 97600 rows have been done ---
# --- 335000 rows have been done ---
# --- 192500 rows have been done ---
# --- 168900 rows have been done ---
# --- 406300 rows have been done ---
# --- 287500 rows have been done ---
# --- 2700 rows have been done ---
# --- 50400 rows have been done ---
# --- 358800 rows have been done ---
# --- 430100 rows have been done ------ 26500 rows have been done ---
#
# --- 121400 rows have been done ---
# --- 263800 rows have been done ---
# --- 311300 rows have been done ---
# --- 73900 rows have been done ---
# --- 382600 rows have been done ---
# --- 216300 rows have been done ---
# --- 240100 rows have been done ---
# --- 453900 rows have been done ---
# --- 145200 rows have been done ---
# --- 97700 rows have been done ---
# --- 335100 rows have been done ---
# --- 192600 rows have been done ---
# --- 169000 rows have been done ---
# --- 406400 rows have been done ---
# --- 287600 rows have been done ---
# --- 2800 rows have been done ---
# --- 50500 rows have been done ---
# --- 358900 rows have been done ---
# --- 26600 rows have been done ------ 430200 rows have been done ---
#
# --- 121500 rows have been done ---
# --- 263900 rows have been done ---
# --- 311400 rows have been done ---
# --- 74000 rows have been done ---
# --- 382700 rows have been done ---
# --- 216400 rows have been done ---
# --- 240200 rows have been done ---
# --- 454000 rows have been done ---
# --- 145300 rows have been done ---
# --- 97800 rows have been done ---
# --- 335200 rows have been done ---
# --- 192700 rows have been done ---
# --- 169100 rows have been done ---
# --- 406500 rows have been done ---
# --- 287700 rows have been done ---
# --- 2900 rows have been done ---
# --- 50600 rows have been done ---
# --- 359000 rows have been done ---
# --- 430300 rows have been done ------ 26700 rows have been done ---
#
# --- 121600 rows have been done ---
# --- 264000 rows have been done ---
# --- 311500 rows have been done ---
# --- 74100 rows have been done ---
# --- 382800 rows have been done ---
# --- 216500 rows have been done ---
# --- 240300 rows have been done ---
# --- 454100 rows have been done ---
# --- 145400 rows have been done ---
# --- 97900 rows have been done ---
# --- 335300 rows have been done ---
# --- 192800 rows have been done ---
# --- 169200 rows have been done ---
# --- 406600 rows have been done ---
# --- 287800 rows have been done ---
# --- 3000 rows have been done ---
# --- 50700 rows have been done ---
# --- 359100 rows have been done ---
# --- 26800 rows have been done ------ 430400 rows have been done ---
#
# --- 121700 rows have been done ---
# --- 264100 rows have been done ---
# --- 311600 rows have been done ---
# --- 74200 rows have been done ---
# --- 382900 rows have been done ---
# --- 216600 rows have been done ---
# --- 240400 rows have been done ---
# --- 454200 rows have been done ---
# --- 145500 rows have been done ---
# --- 98000 rows have been done ---
# --- 335400 rows have been done ---
# --- 192900 rows have been done ---
# --- 169300 rows have been done ---
# --- 406700 rows have been done ---
# --- 287900 rows have been done ---
# --- 3100 rows have been done ---
# --- 50800 rows have been done ---
# --- 359200 rows have been done ---
# --- 430500 rows have been done ------ 26900 rows have been done ---
#
# --- 121800 rows have been done ---
# --- 264200 rows have been done ---
# --- 311700 rows have been done ---
# --- 74300 rows have been done ---
# --- 383000 rows have been done ---
# --- 216700 rows have been done ------ 240500 rows have been done ---
#
# --- 454300 rows have been done ---
# --- 145600 rows have been done ---
# --- 98100 rows have been done ---
# --- 335500 rows have been done ---
# --- 193000 rows have been done ---
# --- 169400 rows have been done ---
# --- 406800 rows have been done ---
# --- 288000 rows have been done ---
# --- 3200 rows have been done ---
# --- 50900 rows have been done ---
# --- 359300 rows have been done ---
# --- 27000 rows have been done ------ 430600 rows have been done ---
#
# --- 121900 rows have been done ---
# --- 264300 rows have been done ---
# --- 311800 rows have been done ---
# --- 74400 rows have been done ---
# --- 383100 rows have been done ---
# --- 240600 rows have been done ---
# --- 216800 rows have been done ---
# --- 454400 rows have been done ---
# --- 145700 rows have been done ---
# --- 98200 rows have been done ---
# --- 335600 rows have been done ---
# --- 193100 rows have been done ---
# --- 169500 rows have been done ---
# --- 406900 rows have been done ---
# --- 288100 rows have been done ---
# --- 51000 rows have been done ---
# --- 3300 rows have been done ---
# --- 359400 rows have been done ---
# --- 430700 rows have been done ------ 27100 rows have been done ---
#
# --- 122000 rows have been done ---
# --- 311900 rows have been done ---
# --- 264400 rows have been done ---
# --- 74500 rows have been done ---
# --- 383200 rows have been done ---
# --- 240700 rows have been done ---
# --- 216900 rows have been done ---
# --- 145800 rows have been done ---
# --- 454500 rows have been done ---
# --- 98300 rows have been done ---
# --- 335700 rows have been done ---
# --- 193200 rows have been done ---
# --- 169600 rows have been done ---
# --- 407000 rows have been done ---
# --- 288200 rows have been done ---
# --- 51100 rows have been done ---
# --- 3400 rows have been done ---
# --- 359500 rows have been done ---
# --- 27200 rows have been done ---
# --- 430800 rows have been done ---
# --- 122100 rows have been done ---
# --- 312000 rows have been done ---
# --- 264500 rows have been done ---
# --- 74600 rows have been done ---
# --- 383300 rows have been done ---
# --- 240800 rows have been done ---
# --- 217000 rows have been done ---
# --- 145900 rows have been done ---
# --- 454600 rows have been done ---
# --- 98400 rows have been done ---
# --- 335800 rows have been done ---
# --- 193300 rows have been done ---
# --- 169700 rows have been done ---
# --- 407100 rows have been done ---
# --- 288300 rows have been done ---
# --- 51200 rows have been done ---
# --- 3500 rows have been done ---
# --- 359600 rows have been done ---
# --- 27300 rows have been done ------ 430900 rows have been done ---
#
# --- 122200 rows have been done ---
# --- 312100 rows have been done ---
# --- 264600 rows have been done ---
# --- 74700 rows have been done ---
# --- 383400 rows have been done ---
# --- 240900 rows have been done ---
# --- 217100 rows have been done ---
# --- 146000 rows have been done ---
# --- 454700 rows have been done ---
# --- 98500 rows have been done ---
# --- 335900 rows have been done ---
# --- 193400 rows have been done ---
# --- 169800 rows have been done ---
# --- 407200 rows have been done ---
# --- 288400 rows have been done ---
# --- 51300 rows have been done ---
# --- 3600 rows have been done ---
# --- 359700 rows have been done ---
# --- 431000 rows have been done ---
# --- 27400 rows have been done ---
# --- 122300 rows have been done ---
# --- 312200 rows have been done ---
# --- 264700 rows have been done ---
# --- 74800 rows have been done ---
# --- 383500 rows have been done ---
# --- 241000 rows have been done ---
# --- 217200 rows have been done ---
# --- 146100 rows have been done ---
# --- 454800 rows have been done ---
# --- 98600 rows have been done ---
# --- 336000 rows have been done ---
# --- 193500 rows have been done ---
# --- 169900 rows have been done ---
# --- 407300 rows have been done ---
# --- 288500 rows have been done ---
# --- 51400 rows have been done ---
# --- 3700 rows have been done ---
# --- 359800 rows have been done ---
# --- 431100 rows have been done ---
# --- 27500 rows have been done ---
# --- 122400 rows have been done ---
# --- 312300 rows have been done ---
# --- 264800 rows have been done ---
# --- 74900 rows have been done ---
# --- 383600 rows have been done ---
# --- 241100 rows have been done ------ 217300 rows have been done ---
#
# --- 146200 rows have been done ---
# --- 454900 rows have been done ---
# --- 98700 rows have been done ---
# --- 336100 rows have been done ---
# --- 193600 rows have been done ---
# --- 170000 rows have been done ---
# --- 407400 rows have been done ---
# --- 288600 rows have been done ---
# --- 51500 rows have been done ---
# --- 3800 rows have been done ---
# --- 359900 rows have been done ---
# --- 431200 rows have been done ------ 27600 rows have been done ---
#
# --- 122500 rows have been done ---
# --- 312400 rows have been done ---
# --- 264900 rows have been done ---
# --- 75000 rows have been done ---
# --- 383700 rows have been done ---
# --- 217400 rows have been done ---
# --- 241200 rows have been done ---
# --- 146300 rows have been done ---
# --- 455000 rows have been done ---
# --- 98800 rows have been done ---
# --- 336200 rows have been done ---
# --- 193700 rows have been done ---
# --- 170100 rows have been done ---
# --- 407500 rows have been done ---
# --- 288700 rows have been done ---
# --- 51600 rows have been done ---
# --- 3900 rows have been done ---
# --- 360000 rows have been done ---
# --- 27700 rows have been done ------ 431300 rows have been done ---
#
# --- 122600 rows have been done ---
# --- 312500 rows have been done ---
# --- 265000 rows have been done ---
# --- 75100 rows have been done ---
# --- 383800 rows have been done ---
# --- 217500 rows have been done ---
# --- 241300 rows have been done ---
# --- 146400 rows have been done ---
# --- 455100 rows have been done ---
# --- 98900 rows have been done ---
# --- 336300 rows have been done ---
# --- 193800 rows have been done ---
# --- 170200 rows have been done ---
# --- 407600 rows have been done ---
# --- 288800 rows have been done ---
# --- 51700 rows have been done ---
# --- 4000 rows have been done ---
# --- 360100 rows have been done ---
# --- 431400 rows have been done ------ 27800 rows have been done ---
#
# --- 122700 rows have been done ---
# --- 312600 rows have been done ---
# --- 265100 rows have been done ---
# --- 75200 rows have been done ---
# --- 383900 rows have been done ---
# --- 217600 rows have been done ------ 241400 rows have been done ---
#
# --- 146500 rows have been done ---
# --- 455200 rows have been done ---
# --- 99000 rows have been done ---
# --- 336400 rows have been done ---
# --- 193900 rows have been done ---
# --- 170300 rows have been done ---
# --- 407700 rows have been done ---
# --- 288900 rows have been done ---
# --- 51800 rows have been done ---
# --- 4100 rows have been done ---
# --- 360200 rows have been done ---
# --- 27900 rows have been done ------ 431500 rows have been done ---
#
# --- 122800 rows have been done ---
# --- 312700 rows have been done ---
# --- 265200 rows have been done ---
# --- 75300 rows have been done ---
# --- 384000 rows have been done ---
# --- 241500 rows have been done ---
# --- 217700 rows have been done ---
# --- 146600 rows have been done ---
# --- 455300 rows have been done ---
# --- 99100 rows have been done ---
# --- 336500 rows have been done ---
# --- 194000 rows have been done ---
# --- 170400 rows have been done ---
# --- 407800 rows have been done ---
# --- 289000 rows have been done ---
# --- 51900 rows have been done ---
# --- 4200 rows have been done ---
# --- 360300 rows have been done ---
# --- 431600 rows have been done ---
# --- 28000 rows have been done ---
# --- 122900 rows have been done ---
# --- 312800 rows have been done ---
# --- 265300 rows have been done ---
# --- 75400 rows have been done ---
# --- 384100 rows have been done ---
# --- 241600 rows have been done ------ 217800 rows have been done ---
#
# --- 146700 rows have been done ---
# --- 455400 rows have been done ---
# --- 99200 rows have been done ---
# --- 336600 rows have been done ---
# --- 194100 rows have been done ---
# --- 170500 rows have been done ---
# --- 407900 rows have been done ---
# --- 289100 rows have been done ---
# --- 52000 rows have been done ---
# --- 4300 rows have been done ---
# --- 360400 rows have been done ---
# --- 431700 rows have been done ------ 28100 rows have been done ---
#
# --- 123000 rows have been done ---
# --- 312900 rows have been done ---
# --- 265400 rows have been done ---
# --- 75500 rows have been done ---
# --- 384200 rows have been done ---
# --- 217900 rows have been done ---
# --- 241700 rows have been done ---
# --- 146800 rows have been done ---
# --- 455500 rows have been done ---
# --- 99300 rows have been done ---
# --- 336700 rows have been done ---
# --- 194200 rows have been done ---
# --- 170600 rows have been done ---
# --- 408000 rows have been done ---
# --- 289200 rows have been done ---
# --- 52100 rows have been done ---
# --- 4400 rows have been done ---
# --- 360500 rows have been done ---
# --- 28200 rows have been done ------ 431800 rows have been done ---
#
# --- 123100 rows have been done ---
# --- 313000 rows have been done ---
# --- 265500 rows have been done ---
# --- 75600 rows have been done ---
# --- 384300 rows have been done ---
# --- 218000 rows have been done ------ 241800 rows have been done ---
#
# --- 146900 rows have been done ---
# --- 455600 rows have been done ---
# --- 99400 rows have been done ---
# --- 336800 rows have been done ---
# --- 194300 rows have been done ---
# --- 170700 rows have been done ---
# --- 408100 rows have been done ---
# --- 289300 rows have been done ---
# --- 52200 rows have been done ---
# --- 4500 rows have been done ---
# --- 360600 rows have been done ---
# --- 431900 rows have been done ------ 28300 rows have been done ---
#
# --- 123200 rows have been done ---
# --- 313100 rows have been done ---
# --- 265600 rows have been done ---
# --- 75700 rows have been done ---
# --- 384400 rows have been done ---
# --- 241900 rows have been done ------ 218100 rows have been done ---
#
# --- 147000 rows have been done ---
# --- 455700 rows have been done ---
# --- 99500 rows have been done ---
# --- 336900 rows have been done ---
# --- 194400 rows have been done ---
# --- 170800 rows have been done ---
# --- 408200 rows have been done ---
# --- 289400 rows have been done ---
# --- 52300 rows have been done ---
# --- 4600 rows have been done ---
# --- 360700 rows have been done ---
# --- 28400 rows have been done ------ 432000 rows have been done ---
#
# --- 123300 rows have been done ---
# --- 313200 rows have been done ---
# --- 265700 rows have been done ---
# --- 75800 rows have been done ---
# --- 384500 rows have been done ---
# --- 218200 rows have been done ------ 242000 rows have been done ---
#
# --- 147100 rows have been done ---
# --- 455800 rows have been done ---
# --- 99600 rows have been done ---
# --- 337000 rows have been done ---
# --- 194500 rows have been done ---
# --- 170900 rows have been done ---
# --- 408300 rows have been done ---
# --- 289500 rows have been done ---
# --- 52400 rows have been done ---
# --- 4700 rows have been done ---
# --- 360800 rows have been done ---
# --- 432100 rows have been done ------ 28500 rows have been done ---
#
# --- 123400 rows have been done ---
# --- 313300 rows have been done ---
# --- 265800 rows have been done ---
# --- 75900 rows have been done ---
# --- 384600 rows have been done ---
# --- 242100 rows have been done ------ 218300 rows have been done ---
#
# --- 147200 rows have been done ---
# --- 455900 rows have been done ---
# --- 99700 rows have been done ---
# --- 337100 rows have been done ---
# --- 194600 rows have been done ---
# --- 171000 rows have been done ---
# --- 408400 rows have been done ---
# --- 289600 rows have been done ---
# --- 52500 rows have been done ---
# --- 4800 rows have been done ---
# --- 360900 rows have been done ---
# --- 28600 rows have been done ------ 432200 rows have been done ---
#
# --- 123500 rows have been done ---
# --- 313400 rows have been done ---
# --- 265900 rows have been done ---
# --- 76000 rows have been done ---
# --- 384700 rows have been done ---
# --- 218400 rows have been done ---
# --- 242200 rows have been done ---
# --- 147300 rows have been done ---
# --- 456000 rows have been done ---
# --- 99800 rows have been done ---
# --- 337200 rows have been done ---
# --- 194700 rows have been done ---
# --- 171100 rows have been done ---
# --- 408500 rows have been done ---
# --- 289700 rows have been done ---
# --- 52600 rows have been done ---
# --- 4900 rows have been done ---
# --- 361000 rows have been done ---
# --- 432300 rows have been done ------ 28700 rows have been done ---
#
# --- 123600 rows have been done ---
# --- 313500 rows have been done ---
# --- 266000 rows have been done ---
# --- 76100 rows have been done ---
# --- 384800 rows have been done ---
# --- 218500 rows have been done ---
# --- 242300 rows have been done ---
# --- 147400 rows have been done ---
# --- 456100 rows have been done ---
# --- 99900 rows have been done ---
# --- 337300 rows have been done ---
# --- 194800 rows have been done ---
# --- 171200 rows have been done ---
# --- 408600 rows have been done ---
# --- 52700 rows have been done ---
# --- 289800 rows have been done ---
# --- 5000 rows have been done ---
# --- 361100 rows have been done ---
# --- 28800 rows have been done ------ 432400 rows have been done ---
#
# --- 123700 rows have been done ---
# --- 313600 rows have been done ---
# --- 266100 rows have been done ---
# --- 76200 rows have been done ---
# --- 384900 rows have been done ---
# --- 218600 rows have been done ---
# --- 242400 rows have been done ---
# --- 147500 rows have been done ---
# --- 456200 rows have been done ---
# --- 100000 rows have been done ---
# --- 337400 rows have been done ---
# --- 194900 rows have been done ---
# --- 171300 rows have been done ---
# --- 408700 rows have been done ---
# --- 52800 rows have been done ------ 289900 rows have been done ---
#
# --- 5100 rows have been done ---
# --- 361200 rows have been done ---
# --- 432500 rows have been done ---
# --- 28900 rows have been done ---
# --- 123800 rows have been done ---
# --- 313700 rows have been done ---
# --- 266200 rows have been done ---
# --- 76300 rows have been done ---
# --- 385000 rows have been done ---
# --- 218700 rows have been done ---
# --- 242500 rows have been done ---
# --- 147600 rows have been done ---
# --- 456300 rows have been done ---
# --- 100100 rows have been done ---
# --- 337500 rows have been done ---
# --- 195000 rows have been done ---
# --- 171400 rows have been done ---
# --- 408800 rows have been done ---
# --- 290000 rows have been done ------ 52900 rows have been done ---
#
# --- 5200 rows have been done ---
# --- 361300 rows have been done ---
# --- 432600 rows have been done ------ 29000 rows have been done ---
#
# --- 123900 rows have been done ---
# --- 313800 rows have been done ---
# --- 266300 rows have been done ---
# --- 76400 rows have been done ---
# --- 385100 rows have been done ---
# --- 218800 rows have been done ---
# --- 242600 rows have been done ---
# --- 147700 rows have been done ---
# --- 456400 rows have been done ---
# --- 100200 rows have been done ---
# --- 337600 rows have been done ---
# --- 195100 rows have been done ---
# --- 171500 rows have been done ---
# --- 408900 rows have been done ---
# --- 53000 rows have been done ------ 290100 rows have been done ---
#
# --- 5300 rows have been done ---
# --- 361400 rows have been done ---
# --- 29100 rows have been done ---
# --- 432700 rows have been done ---
# --- 124000 rows have been done ---
# --- 313900 rows have been done ---
# --- 266400 rows have been done ---
# --- 76500 rows have been done ---
# --- 385200 rows have been done ---
# --- 218900 rows have been done ---
# --- 242700 rows have been done ---
# --- 147800 rows have been done ---
# --- 456500 rows have been done ---
# --- 100300 rows have been done ---
# --- 337700 rows have been done ---
# --- 195200 rows have been done ---
# --- 171600 rows have been done ---
# --- 409000 rows have been done ---
# --- 290200 rows have been done ------ 53100 rows have been done ---
#
# --- 5400 rows have been done ---
# --- 361500 rows have been done ---
# --- 29200 rows have been done ------ 432800 rows have been done ---
#
# --- 124100 rows have been done ---
# --- 314000 rows have been done ---
# --- 266500 rows have been done ---
# --- 76600 rows have been done ---
# --- 385300 rows have been done ---
# --- 219000 rows have been done ---
# --- 242800 rows have been done ---
# --- 147900 rows have been done ---
# --- 456600 rows have been done ---
# --- 100400 rows have been done ---
# --- 337800 rows have been done ---
# --- 195300 rows have been done ---
# --- 171700 rows have been done ---
# --- 409100 rows have been done ---
# --- 53200 rows have been done ------ 290300 rows have been done ---
#
# --- 5500 rows have been done ---
# --- 361600 rows have been done ---
# --- 432900 rows have been done ------ 29300 rows have been done ---
#
# --- 124200 rows have been done ---
# --- 314100 rows have been done ---
# --- 266600 rows have been done ---
# --- 76700 rows have been done ---
# --- 385400 rows have been done ---
# --- 219100 rows have been done ------ 242900 rows have been done ---
#
# --- 148000 rows have been done ---
# --- 456700 rows have been done ---
# --- 100500 rows have been done ---
# --- 337900 rows have been done ---
# --- 195400 rows have been done ---
# --- 171800 rows have been done ---
# --- 409200 rows have been done ---
# --- 290400 rows have been done ------ 53300 rows have been done ---
#
# --- 5600 rows have been done ---
# --- 361700 rows have been done ---
# --- 29400 rows have been done ------ 433000 rows have been done ---
#
# --- 124300 rows have been done ---
# --- 314200 rows have been done ---
# --- 266700 rows have been done ---
# --- 76800 rows have been done ---
# --- 385500 rows have been done ---
# --- 243000 rows have been done ---
# --- 219200 rows have been done ---
# --- 148100 rows have been done ---
# --- 456800 rows have been done ---
# --- 100600 rows have been done ---
# --- 338000 rows have been done ---
# --- 195500 rows have been done ---
# --- 171900 rows have been done ---
# --- 409300 rows have been done ---
# --- 53400 rows have been done ------ 290500 rows have been done ---
#
# --- 5700 rows have been done ---
# --- 361800 rows have been done ---
# --- 433100 rows have been done ------ 29500 rows have been done ---
#
# --- 124400 rows have been done ---
# --- 314300 rows have been done ---
# --- 266800 rows have been done ---
# --- 76900 rows have been done ---
# --- 385600 rows have been done ---
# --- 243100 rows have been done ---
# --- 219300 rows have been done ---
# --- 148200 rows have been done ---
# --- 456900 rows have been done ---
# --- 100700 rows have been done ---
# --- 338100 rows have been done ---
# --- 195600 rows have been done ---
# --- 172000 rows have been done ---
# --- 409400 rows have been done ---
# --- 290600 rows have been done ------ 53500 rows have been done ---
#
# --- 5800 rows have been done ---
# --- 361900 rows have been done ---
# --- 29600 rows have been done ------ 433200 rows have been done ---
#
# --- 124500 rows have been done ---
# --- 314400 rows have been done ---
# --- 266900 rows have been done ---
# --- 77000 rows have been done ---
# --- 385700 rows have been done ---
# --- 243200 rows have been done ---
# --- 219400 rows have been done ---
# --- 148300 rows have been done ---
# --- 457000 rows have been done ---
# --- 100800 rows have been done ---
# --- 338200 rows have been done ---
# --- 195700 rows have been done ---
# --- 172100 rows have been done ---
# --- 409500 rows have been done ---
# --- 53600 rows have been done ------ 290700 rows have been done ---
#
# --- 5900 rows have been done ---
# --- 362000 rows have been done ---
# --- 433300 rows have been done ------ 29700 rows have been done ---
#
# --- 124600 rows have been done ---
# --- 314500 rows have been done ---
# --- 267000 rows have been done ---
# --- 77100 rows have been done ---
# --- 385800 rows have been done ---
# --- 243300 rows have been done ---
# --- 219500 rows have been done ---
# --- 148400 rows have been done ---
# --- 457100 rows have been done ---
# --- 100900 rows have been done ---
# --- 338300 rows have been done ---
# --- 195800 rows have been done ---
# --- 172200 rows have been done ---
# --- 409600 rows have been done ---
# --- 290800 rows have been done ------ 53700 rows have been done ---
#
# --- 6000 rows have been done ---
# --- 362100 rows have been done ---
# --- 29800 rows have been done ------ 433400 rows have been done ---
#
# --- 124700 rows have been done ---
# --- 314600 rows have been done ---
# --- 267100 rows have been done ---
# --- 77200 rows have been done ---
# --- 385900 rows have been done ---
# --- 243400 rows have been done ---
# --- 219600 rows have been done ---
# --- 148500 rows have been done ---
# --- 457200 rows have been done ---
# --- 101000 rows have been done ---
# --- 338400 rows have been done ---
# --- 195900 rows have been done ---
# --- 172300 rows have been done ---
# --- 409700 rows have been done ---
# --- 53800 rows have been done ------ 290900 rows have been done ---
#
# --- 6100 rows have been done ---
# --- 362200 rows have been done ---
# --- 433500 rows have been done ------ 29900 rows have been done ---
#
# --- 124800 rows have been done ---
# --- 314700 rows have been done ---
# --- 267200 rows have been done ---
# --- 77300 rows have been done ---
# --- 386000 rows have been done ---
# --- 243500 rows have been done ---
# --- 219700 rows have been done ---
# --- 148600 rows have been done ---
# --- 457300 rows have been done ---
# --- 101100 rows have been done ---
# --- 338500 rows have been done ---
# --- 196000 rows have been done ---
# --- 172400 rows have been done ---
# --- 409800 rows have been done ---
# --- 291000 rows have been done ------ 53900 rows have been done ---
#
# --- 6200 rows have been done ---
# --- 362300 rows have been done ---
# --- 30000 rows have been done ------ 433600 rows have been done ---
#
# --- 124900 rows have been done ---
# --- 314800 rows have been done ---
# --- 267300 rows have been done ---
# --- 77400 rows have been done ---
# --- 386100 rows have been done ---
# --- 243600 rows have been done ---
# --- 219800 rows have been done ---
# --- 148700 rows have been done ---
# --- 457400 rows have been done ---
# --- 101200 rows have been done ---
# --- 338600 rows have been done ---
# --- 196100 rows have been done ---
# --- 172500 rows have been done ---
# --- 409900 rows have been done ---
# --- 54000 rows have been done ------ 291100 rows have been done ---
#
# --- 6300 rows have been done ---
# --- 362400 rows have been done ---
# --- 433700 rows have been done ------ 30100 rows have been done ---
#
# --- 125000 rows have been done ---
# --- 314900 rows have been done ---
# --- 267400 rows have been done ---
# --- 77500 rows have been done ---
# --- 386200 rows have been done ---
# --- 243700 rows have been done ---
# --- 219900 rows have been done ---
# --- 148800 rows have been done ---
# --- 457500 rows have been done ---
# --- 101300 rows have been done ---
# --- 338700 rows have been done ---
# --- 196200 rows have been done ---
# --- 172600 rows have been done ---
# --- 410000 rows have been done ---
# --- 291200 rows have been done ------ 54100 rows have been done ---
#
# --- 6400 rows have been done ---
# --- 362500 rows have been done ---
# --- 30200 rows have been done ------ 433800 rows have been done ---
#
# --- 125100 rows have been done ---
# --- 315000 rows have been done ---
# --- 267500 rows have been done ---
# --- 77600 rows have been done ---
# --- 386300 rows have been done ---
# --- 243800 rows have been done ---
# --- 220000 rows have been done ---
# --- 148900 rows have been done ---
# --- 457600 rows have been done ---
# --- 101400 rows have been done ---
# --- 338800 rows have been done ---
# --- 196300 rows have been done ---
# --- 172700 rows have been done ---
# --- 410100 rows have been done ---
# --- 54200 rows have been done ------ 291300 rows have been done ---
#
# --- 6500 rows have been done ---
# --- 362600 rows have been done ---
# --- 433900 rows have been done ------ 30300 rows have been done ---
#
# --- 125200 rows have been done ---
# --- 315100 rows have been done ---
# --- 267600 rows have been done ---
# --- 77700 rows have been done ---
# --- 386400 rows have been done ---
# --- 243900 rows have been done ---
# --- 220100 rows have been done ---
# --- 149000 rows have been done ---
# --- 457700 rows have been done ---
# --- 101500 rows have been done ---
# --- 338900 rows have been done ---
# --- 196400 rows have been done ---
# --- 172800 rows have been done ---
# --- 410200 rows have been done ---
# --- 291400 rows have been done ------ 54300 rows have been done ---
#
# --- 6600 rows have been done ---
# --- 362700 rows have been done ---
# --- 30400 rows have been done ------ 434000 rows have been done ---
#
# --- 125300 rows have been done ---
# --- 315200 rows have been done ---
# --- 267700 rows have been done ---
# --- 77800 rows have been done ---
# --- 386500 rows have been done ---
# --- 244000 rows have been done ---
# --- 220200 rows have been done ---
# --- 149100 rows have been done ---
# --- 457800 rows have been done ---
# --- 101600 rows have been done ---
# --- 339000 rows have been done ---
# --- 196500 rows have been done ---
# --- 172900 rows have been done ---
# --- 410300 rows have been done ---
# --- 54400 rows have been done ---
# --- 291500 rows have been done ---
# --- 6700 rows have been done ---
# --- 362800 rows have been done ---
# --- 434100 rows have been done ------ 30500 rows have been done ---
#
# --- 125400 rows have been done ---
# --- 315300 rows have been done ---
# --- 267800 rows have been done ---
# --- 77900 rows have been done ---
# --- 386600 rows have been done ---
# --- 244100 rows have been done ---
# --- 220300 rows have been done ---
# --- 149200 rows have been done ---
# --- 457900 rows have been done ---
# --- 101700 rows have been done ---
# --- 339100 rows have been done ---
# --- 196600 rows have been done ---
# --- 173000 rows have been done ---
# --- 410400 rows have been done ---
# --- 54500 rows have been done ------ 291600 rows have been done ---
#
# --- 6800 rows have been done ---
# --- 362900 rows have been done ---
# --- 30600 rows have been done ------ 434200 rows have been done ---
#
# --- 125500 rows have been done ---
# --- 315400 rows have been done ---
# --- 267900 rows have been done ---
# --- 78000 rows have been done ---
# --- 386700 rows have been done ---
# --- 244200 rows have been done ---
# --- 220400 rows have been done ---
# --- 149300 rows have been done ---
# --- 458000 rows have been done ---
# --- 101800 rows have been done ---
# --- 339200 rows have been done ---
# --- 196700 rows have been done ---
# --- 173100 rows have been done ---
# --- 410500 rows have been done ---
# --- 291700 rows have been done ---
# --- 54600 rows have been done ---
# --- 6900 rows have been done ---
# --- 363000 rows have been done ---
# --- 434300 rows have been done ------ 30700 rows have been done ---
#
# --- 125600 rows have been done ---
# --- 315500 rows have been done ---
# --- 268000 rows have been done ---
# --- 78100 rows have been done ---
# --- 386800 rows have been done ---
# --- 244300 rows have been done ---
# --- 220500 rows have been done ---
# --- 149400 rows have been done ---
# --- 458100 rows have been done ---
# --- 101900 rows have been done ---
# --- 339300 rows have been done ---
# --- 196800 rows have been done ---
# ...
# --- 425300 rows have been done ---
# --- 306500 rows have been done ------ 69400 rows have been done ---
# --- 21700 rows have been done ---
#
# --- 377800 rows have been done ---
# --- 330300 rows have been done ---
# --- 449100 rows have been done ---
# --- 45500 rows have been done ---
# --- 140400 rows have been done ---
# --- 282800 rows have been done ---
# --- 92900 rows have been done ---
# --- 401600 rows have been done ---
# --- 164200 rows have been done ---
# --- 259100 rows have been done ---
# --- 472900 rows have been done ---
# --- 235300 rows have been done ---
# --- 116700 rows have been done ---
# --- 354100 rows have been done ---
# --- 211600 rows have been done ---
# --- 188000 rows have been done ---
# --- 425400 rows have been done ---
# --- 69500 rows have been done ------ 21800 rows have been done ---
# --- 306600 rows have been done ---
#
# --- 377900 rows have been done ---
# --- 330400 rows have been done ---
# --- 449200 rows have been done ---
# --- 45600 rows have been done ---
# --- 140500 rows have been done ---
# --- 282900 rows have been done ---
# --- 93000 rows have been done ---
# --- 401700 rows have been done ---
# --- 164300 rows have been done ---
# --- 259200 rows have been done ---
# --- 473000 rows have been done ---
# --- 235400 rows have been done ---
# --- 116800 rows have been done ---
# --- 354200 rows have been done ---
# --- 211700 rows have been done ---
# --- 188100 rows have been done ---
# --- 425500 rows have been done ---
# --- 21900 rows have been done ------ 306700 rows have been done ---
#
# --- 69600 rows have been done ---
# --- 378000 rows have been done ---
# --- 330500 rows have been done ---
# --- 449300 rows have been done ---
# --- 45700 rows have been done ---
# --- 140600 rows have been done ---
# --- 283000 rows have been done ---
# --- 93100 rows have been done ---
# --- 401800 rows have been done ---
# --- 164400 rows have been done ---
# --- 259300 rows have been done ---
# --- 473100 rows have been done ---
# --- 235500 rows have been done ---
# --- 116900 rows have been done ---
# --- 354300 rows have been done ---
# --- 211800 rows have been done ---
# --- 188200 rows have been done ---
# --- 425600 rows have been done ---
# --- 306800 rows have been done ------ 22000 rows have been done ---
# --- 69700 rows have been done ---
#
# --- 378100 rows have been done ---
# --- 330600 rows have been done ---
# --- 449400 rows have been done ---
# --- 45800 rows have been done ---
# --- 140700 rows have been done ---
# --- 283100 rows have been done ---
# --- 93200 rows have been done ---
# --- 401900 rows have been done ---
# --- 164500 rows have been done ---
# --- 259400 rows have been done ---
# --- 473200 rows have been done ---
# --- 235600 rows have been done ---
# --- 117000 rows have been done ---
# --- 354400 rows have been done ---
# --- 211900 rows have been done ---
# --- 188300 rows have been done ---
# --- 425700 rows have been done ---
# --- 22100 rows have been done ------ 69800 rows have been done ---
# --- 306900 rows have been done ---
#
# --- 378200 rows have been done ---
# --- 330700 rows have been done ---
# --- 449500 rows have been done ---
# --- 45900 rows have been done ---
# --- 140800 rows have been done ---
# --- 283200 rows have been done ---
# --- 93300 rows have been done ------ 402000 rows have been done ---
#
# --- 164600 rows have been done ---
# --- 259500 rows have been done ---
# --- 473300 rows have been done ---
# --- 235700 rows have been done ---
# --- 117100 rows have been done ---
# --- 354500 rows have been done ---
# --- 212000 rows have been done ---
# --- 188400 rows have been done ---
# --- 425800 rows have been done ---
# --- 69900 rows have been done ------ 307000 rows have been done ---
#
# --- 22200 rows have been done ---
# --- 378300 rows have been done ---
# --- 330800 rows have been done ---
# --- 449600 rows have been done ---
# --- 46000 rows have been done ---
# --- 140900 rows have been done ---
# --- 283300 rows have been done ---
# --- 402100 rows have been done ---
# --- 93400 rows have been done ---
# --- 164700 rows have been done ---
# --- 259600 rows have been done ---
# --- 473400 rows have been done ---
# --- 235800 rows have been done ---
# --- 117200 rows have been done ---
# --- 354600 rows have been done ---
# --- 212100 rows have been done ---
# --- 188500 rows have been done ---
# --- 425900 rows have been done ---
# --- 307100 rows have been done ------ 70000 rows have been done ---
# --- 22300 rows have been done ---
#
# --- 378400 rows have been done ---
# --- 330900 rows have been done ---
# --- 449700 rows have been done ---
# --- 46100 rows have been done ---
# --- 141000 rows have been done ---
# --- 283400 rows have been done ---
# --- 402200 rows have been done ---
# --- 93500 rows have been done ---
# --- 164800 rows have been done ---
# --- 259700 rows have been done ---
# --- 473500 rows have been done ---
# --- 235900 rows have been done ---
# --- 117300 rows have been done ---
# --- 354700 rows have been done ---
# --- 212200 rows have been done ---
# --- 188600 rows have been done ---
# --- 426000 rows have been done ---
# --- 70100 rows have been done ------ 22400 rows have been done ---
# --- 307200 rows have been done ---
#
# --- 378500 rows have been done ---
# --- 331000 rows have been done ---
# --- 449800 rows have been done ---
# --- 46200 rows have been done ---
# --- 141100 rows have been done ---
# --- 283500 rows have been done ---
# --- 402300 rows have been done ---
# --- 93600 rows have been done ---
# --- 164900 rows have been done ---
# --- 259800 rows have been done ---
# --- 473600 rows have been done ---
# --- 236000 rows have been done ---
# --- 117400 rows have been done ---
# --- 354800 rows have been done ---
# --- 212300 rows have been done ---
# --- 188700 rows have been done ---
# --- 426100 rows have been done ---
# --- 22500 rows have been done ---
# --- 307300 rows have been done ---
# --- 70200 rows have been done ---
# --- 378600 rows have been done ---
# --- 331100 rows have been done ---
# --- 449900 rows have been done ---
# --- 46300 rows have been done ---
# --- 141200 rows have been done ---
# --- 283600 rows have been done ---
# --- 402400 rows have been done ------ 93700 rows have been done ---
#
# --- 165000 rows have been done ---
# --- 259900 rows have been done ---
# --- 473700 rows have been done ---
# --- 236100 rows have been done ---
# --- 117500 rows have been done ---
# --- 354900 rows have been done ---
# --- 212400 rows have been done ---
# --- 188800 rows have been done ---
# --- 426200 rows have been done ---
# --- 22600 rows have been done ------ 307400 rows have been done ---
# --- 70300 rows have been done ---
#
# --- 378700 rows have been done ---
# --- 331200 rows have been done ---
# --- 450000 rows have been done ---
# --- 46400 rows have been done ---
# --- 141300 rows have been done ---
# --- 283700 rows have been done ---
# --- 93800 rows have been done ------ 402500 rows have been done ---
#
# --- 165100 rows have been done ---
# --- 260000 rows have been done ---
# --- 473800 rows have been done ---
# --- 236200 rows have been done ---
# --- 117600 rows have been done ---
# --- 355000 rows have been done ---
# --- 212500 rows have been done ---
# --- 188900 rows have been done ---
# --- 426300 rows have been done ---
# --- 307500 rows have been done ------ 70400 rows have been done ---
#
# --- 22700 rows have been done ---
# --- 378800 rows have been done ---
# --- 331300 rows have been done ------ 450100 rows have been done ---
#
# --- 46500 rows have been done ---
# --- 141400 rows have been done ---
# --- 283800 rows have been done ---
# --- 402600 rows have been done ------ 93900 rows have been done ---
#
# --- 165200 rows have been done ---
# --- 260100 rows have been done ---
# --- 473900 rows have been done ---
# --- 236300 rows have been done ---
# --- 117700 rows have been done ---
# --- 355100 rows have been done ---
# --- 212600 rows have been done ---
# --- 189000 rows have been done ---
# --- 426400 rows have been done ---
# --- 70500 rows have been done ------ 307600 rows have been done ---
#
# --- 22800 rows have been done ---
# --- 378900 rows have been done ---
# --- 450200 rows have been done ------ 331400 rows have been done ---
# --- 46600 rows have been done ---
#
# --- 141500 rows have been done ---
# --- 283900 rows have been done ---
# --- 94000 rows have been done ------ 402700 rows have been done ---
#
# --- 165300 rows have been done ---
# --- 260200 rows have been done ---
# --- 474000 rows have been done ---
# --- 236400 rows have been done ---
# --- 117800 rows have been done ---
# --- 355200 rows have been done ---
# --- 212700 rows have been done ---
# --- 189100 rows have been done ---
# --- 426500 rows have been done ---
# --- 307700 rows have been done ------ 70600 rows have been done ---
# --- 22900 rows have been done ---
#
# --- 379000 rows have been done ---
# --- 331500 rows have been done ------ 46700 rows have been done ---
# --- 450300 rows have been done ---
#
# --- 141600 rows have been done ---
# --- 284000 rows have been done ---
# --- 402800 rows have been done ------ 94100 rows have been done ---
#
# --- 165400 rows have been done ---
# --- 260300 rows have been done ---
# --- 474100 rows have been done ---
# --- 236500 rows have been done ---
# --- 117900 rows have been done ---
# --- 355300 rows have been done ---
# --- 212800 rows have been done ---
# --- 189200 rows have been done ---
# --- 426600 rows have been done ---
# --- 70700 rows have been done ------ 23000 rows have been done ---
# --- 307800 rows have been done ---
#
# --- 379100 rows have been done ---
# --- 46800 rows have been done ------ 450400 rows have been done ---
#
# --- 331600 rows have been done ---
# --- 141700 rows have been done ---
# --- 284100 rows have been done ---
# --- 94200 rows have been done ------ 402900 rows have been done ---
#
# --- 165500 rows have been done ---
# --- 260400 rows have been done ---
# --- 474200 rows have been done ---
# --- 236600 rows have been done ---
# --- 118000 rows have been done ---
# --- 355400 rows have been done ---
# --- 212900 rows have been done ---
# --- 189300 rows have been done ---
# --- 426700 rows have been done ---
# --- 23100 rows have been done ------ 307900 rows have been done ---
# --- 70800 rows have been done ---
#
# --- 379200 rows have been done ---
# --- 450500 rows have been done ------ 46900 rows have been done ---
#
# --- 331700 rows have been done ---
# --- 141800 rows have been done ---
# --- 284200 rows have been done ---
# --- 403000 rows have been done ------ 94300 rows have been done ---
#
# --- 165600 rows have been done ---
# --- 260500 rows have been done ---
# --- 474300 rows have been done ---
# --- 236700 rows have been done ---
# --- 118100 rows have been done ---
# --- 355500 rows have been done ---
# --- 213000 rows have been done ---
# --- 189400 rows have been done ---
# --- 426800 rows have been done ---
# --- 308000 rows have been done ------ 70900 rows have been done ---
# --- 23200 rows have been done ---
#
# --- 379300 rows have been done ---
# --- 47000 rows have been done ------ 450600 rows have been done ---
# --- 331800 rows have been done ---
#
# --- 141900 rows have been done ---
# --- 284300 rows have been done ---
# --- 94400 rows have been done ------ 403100 rows have been done ---
#
# --- 165700 rows have been done ---
# --- 260600 rows have been done ---
# --- 474400 rows have been done ---
# --- 236800 rows have been done ---
# --- 118200 rows have been done ---
# --- 355600 rows have been done ---
# --- 213100 rows have been done ---
# --- 189500 rows have been done ---
# --- 426900 rows have been done ---
# --- 71000 rows have been done ------ 23300 rows have been done ---
#
# --- 308100 rows have been done ---
# --- 379400 rows have been done ---
# --- 450700 rows have been done ------ 331900 rows have been done ---
# --- 47100 rows have been done ---
#
# --- 142000 rows have been done ---
# --- 284400 rows have been done ---
# --- 403200 rows have been done ------ 94500 rows have been done ---
#
# --- 165800 rows have been done ---
# --- 260700 rows have been done ---
# --- 474500 rows have been done ---
# --- 236900 rows have been done ---
# --- 118300 rows have been done ---
# --- 355700 rows have been done ---
# --- 213200 rows have been done ---
# --- 189600 rows have been done ---
# --- 427000 rows have been done ---
# --- 23400 rows have been done ------ 71100 rows have been done ---
# --- 308200 rows have been done ---
#
# --- 379500 rows have been done ---
# --- 332000 rows have been done ------ 47200 rows have been done ---
#
# --- 450800 rows have been done ---
# --- 142100 rows have been done ---
# --- 284500 rows have been done ---
# --- 94600 rows have been done ------ 403300 rows have been done ---
#
# --- 165900 rows have been done ---
# --- 260800 rows have been done ---
# --- 474600 rows have been done ---
# --- 237000 rows have been done ---
# --- 118400 rows have been done ---
# --- 355800 rows have been done ---
# --- 213300 rows have been done ---
# --- 189700 rows have been done ---
# --- 427100 rows have been done ---
# --- 71200 rows have been done ------ 308300 rows have been done ---
# --- 23500 rows have been done ---
#
# --- 379600 rows have been done ---
# --- 47300 rows have been done ------ 332100 rows have been done ---
#
# --- 450900 rows have been done ---
# --- 142200 rows have been done ---
# --- 284600 rows have been done ---
# --- 403400 rows have been done ------ 94700 rows have been done ---
#
# --- 166000 rows have been done ---
# --- 260900 rows have been done ---
# --- 474700 rows have been done ---
# --- 237100 rows have been done ---
# --- 118500 rows have been done ---
# --- 355900 rows have been done ---
# --- 213400 rows have been done ---
# --- 189800 rows have been done ---
# --- 427200 rows have been done ---
# --- 308400 rows have been done ------ 23600 rows have been done ---
#
# --- 379700 rows have been done ---
# --- 332200 rows have been done ------ 47400 rows have been done ---
#
# --- 451000 rows have been done ---
# --- 142300 rows have been done ---
# --- 284700 rows have been done ---
# --- 94800 rows have been done ------ 403500 rows have been done ---
#
# --- 166100 rows have been done ---
# --- 261000 rows have been done ---
# --- 474800 rows have been done ---
# --- 237200 rows have been done ---
# --- 118600 rows have been done ---
# --- 356000 rows have been done ---
# --- 213500 rows have been done ---
# --- 189900 rows have been done ---
# --- 427300 rows have been done ---
# --- 23700 rows have been done ------ 308500 rows have been done ---
#
# --- 379800 rows have been done ---
# --- 47500 rows have been done ------ 332300 rows have been done ---
# --- 451100 rows have been done ---
#
# --- 142400 rows have been done ---
# --- 284800 rows have been done ---
# --- 403600 rows have been done ------ 94900 rows have been done ---
#
# --- 166200 rows have been done ---
# --- 261100 rows have been done ---
# --- 474900 rows have been done ---
# --- 237300 rows have been done ---
# --- 118700 rows have been done ---
# --- 356100 rows have been done ---
# --- 213600 rows have been done ---
# --- 190000 rows have been done ---
# --- 427400 rows have been done ---
# --- 308600 rows have been done ---
# --- 379900 rows have been done ---
# --- 332400 rows have been done ---
# --- 451200 rows have been done ---
# --- 142500 rows have been done ---
# --- 284900 rows have been done ---
# --- 95000 rows have been done ------ 403700 rows have been done ---
#
# --- 166300 rows have been done ---
# --- 261200 rows have been done ---
# --- 475000 rows have been done ---
# --- 237400 rows have been done ---
# --- 118800 rows have been done ---
# --- 356200 rows have been done ---
# --- 213700 rows have been done ---
# --- 427500 rows have been done ---
# --- 308700 rows have been done ---
# --- 380000 rows have been done ---
# --- 332500 rows have been done ---
# --- 451300 rows have been done ---
# --- 285000 rows have been done ---
# --- 403800 rows have been done ---
# --- 261300 rows have been done ---
# --- 475100 rows have been done ---
# --- 237500 rows have been done ---
# --- 356300 rows have been done ---
# --- 213800 rows have been done ---
# --- 427600 rows have been done ---
# --- 308800 rows have been done ---
# --- 380100 rows have been done ---
# --- 332600 rows have been done ------ 451400 rows have been done ---
#
# --- 285100 rows have been done ---
# --- 403900 rows have been done ---
# --- 475200 rows have been done ------ 237600 rows have been done ---
#
# --- 356400 rows have been done ---
# --- 427700 rows have been done ---
# --- 308900 rows have been done ---
# All threads have finished processing.

# %%
extraction_df.to_excel("News_output\\News_training_domain_set_withCompany.xlsx", index=False)

# %% [markdown]
# ## 2. Search by Rules of Similarity-judged Trigger Words for Application Domain Set

# %% [markdown]
# ### 2.1. Abbreviation Generation

# %%
import json
import jieba
import re

# Reading the JSON File containing "A-share Company Information"
with open("News_input\\A_share_list\\A_share_list.json", "r", encoding="utf-8") as file:
    a_share_list = json.load(file)

# String Processing and Abbreviation Generation for All the Company Names
for company in a_share_list:
    # 1. Simplifying the full name
    fullname = company["fullname"]
    if "股份有限公司" in fullname:
        partname = fullname.replace("股份有限公司", "")
    else:
        partname = fullname
    company["partname"] = partname
    
    # 2. Generating Nickname (abbreviation)
    partname = re.sub(r'[(（][^)）]+[)）]', '', partname)
    if len(company["partname"]) <= 3: 
        company["abbreviation"] = company["partname"]
    else:  # Generating Nickname using JIEBA Tokenization when the simplified full name is not simple enough
        words = jieba.lcut(partname)  
        name = re.sub(r'[a-zA-Z@#$%^&*()！~\[\]{};:,.<>?/\\|]', '', company["name"]) 
        if "退市" in name:
            name = name.replace("退市", "")
        if len(words) == 1:
            # If there's only one word, keep abbreviation consistent with the partname
            company["abbreviation"] = partname
        elif len(words[0]) >= 2 and words[0][0] != name[0]:
            # If the first word has at least 2 characters and doesn't match the first letter of the name, remove it
            company["abbreviation"] = "".join(words[1:])  
        elif len(words[0]) == 1 and words[0][0] != name[0]:
            # If the first word has 1 character and doesn't match the first two letters of the name, remove it
            company["abbreviation"] = "".join(words[2:])
        else:
            # Otherwise, assuming all words are keywords, keep the partname unchanged
            partname = "".join(words)
            company["abbreviation"] = partname
    
    # Removing words like "集团", "控股", "科技" from the abbreviation if present
    del_words = ["集团","控股","科技"]
    for del_word in del_words:
        if del_word in company["abbreviation"]:
            abbreviation_correct = company["abbreviation"].replace(del_word, "")
            if len(abbreviation_correct) > 2:
                # If it's less than or equal to 2 characters, don't remove; otherwise, remove
                company["abbreviation"] = abbreviation_correct
                
    # Handling cautiously when the length of abbreviation is less than or equal to 3 resembling common words like "雪人"
    if len(company["abbreviation"]) <= 3:
        # Removing English and special characters from name, removing "股份" from name
        if not re.search(r'[a-zA-Z]', partname):
            name_correct = re.sub(r'[a-zA-Z@#$%^&*()！~\[\]{};:,.<>?/\\|]', '', company["name"])  
        if "股份" in name_correct:
            name_correct = name_correct.replace("股份", "")
        # If name is not contained in abbreviation, be cautious
        if name_correct not in company["abbreviation"]:
            company["abbreviation"] = name_correct
    
    # Outputting the construction of this dictionary entry
    print(f'{company["name"]}: from {company["partname"]} to {company["abbreviation"]}')

# Creating a new JSON file and writing the updated data into it
with open("News_input\\A_share_list\\A_share_list_with_abbreviation.json", "w", encoding="utf-8") as new_file:
    json.dump(a_share_list, new_file, ensure_ascii=False, indent=2)

print("New JSON file created with 'partname' and 'abbreviation' fields.")
# Out:
# 邵阳液压:from 邵阳维克液压to邵阳维克液压
# 同益中:from 北京同益中新材料科技to同益中新材料
# 华瓷股份:from 湖南华联瓷业to华联瓷业
# 鸿富瀚:from 深圳市鸿富瀚科技to鸿富瀚
# 高铁电气:from 中铁高铁电气装备to高铁电气装备
# 严牌股份:from 浙江严牌过滤技术to严牌过滤技术
# 百胜智能:from 江西百胜智能科技to百胜智能
# 青岛食品:from 青岛食品to青岛食品
# 德昌股份:from 宁波德昌电机to德昌电机
# 中自科技:from 中自环保科技to中自环保
# 富吉瑞:from 北京富吉瑞光电科技to富吉瑞光电
# 新瀚新材:from 江苏新瀚新材料to新瀚新材料
# 春雪食品:from 春雪食品集团to春雪食品
# 孩子王:from 孩子王儿童用品to孩子王儿童用品
# 丽臣实业:from 湖南丽臣实业to丽臣实业
# 珠海冠宇:from 珠海冠宇电池to珠海冠宇电池
# 百普赛斯:from 北京百普赛斯生物科技to百普赛斯生物
# 多瑞医药:from 西藏多瑞医药to多瑞医药
# 亚康股份:from 北京亚康万玮信息技术to亚康万玮信息技术
# 凯盛新材:from 山东凯盛新材料to凯盛新材料
# 中国能建:from 中国能源建设to中国能源建设
# 大地海洋:from 杭州大地海洋环保to大地海洋环保
with open("News_input\\A_share_list\\A_share_list_with_abbreviation.json", "r", encoding="utf-8") as file:
    a_share_list = json.load(file)
LEN2_abbreviation = []
LEN3_abbreviation = []
LEN4_abbreviation = []
LEN5_abbreviation = []
LEN6_abbreviation = []
LEN7_abbreviation = []
LEN8plus_abbreviation = []

for company in a_share_list:
    if len(company['abbreviation'])==2:
        LEN2_abbreviation.append(company['abbreviation'])
    if len(company['abbreviation'])==3:
        LEN3_abbreviation.append(company['abbreviation'])
    if len(company['abbreviation'])==4:
        LEN4_abbreviation.append(company['abbreviation'])
    if len(company['abbreviation'])==5:
        LEN5_abbreviation.append(company['abbreviation'])
    if len(company['abbreviation'])==6:
        LEN6_abbreviation.append(company['abbreviation'])
    if len(company['abbreviation'])==7:
        LEN7_abbreviation.append(company['abbreviation'])
    if len(company['abbreviation'])>=8:
        LEN8plus_abbreviation.append(company['abbreviation'])

        
print(f'Length 2 abbreviation: {len(LEN2_abbreviation)}')
print(f'Length 3 abbreviation: {len(LEN3_abbreviation)}')
print(f'Length 4 abbreviation: {len(LEN4_abbreviation)}')
print(f'Length 5 abbreviation: {len(LEN5_abbreviation)}')
print(f'Length 6 abbreviation: {len(LEN6_abbreviation)}')
print(f'Length 7 abbreviation: {len(LEN7_abbreviation)}')
print(f'Length greater than or equal to 8 abbreviation: {len(LEN8plus_abbreviation)}')

# Manually filter common words that are still in aliases, common words are generally two characters long:
print("\nCommon words are generally two characters long, abbreviation with two characters:")
print(LEN2_abbreviation)
# Out:
# Length 2 abbreviation: 120
# Length 3 abbreviation: 192
# Length 4 abbreviation: 2405
# Length 5 abbreviation: 438
# Length 6 abbreviation: 898
# Length 7 abbreviation: 247
# Length greater than or equal to 8 abbreviation: 354
#
# Common words are generally two characters long, abbreviation with two characters:
# ['久祺', '新柴', '爱慕', '恒帅', '泰坦', '欣贺', '美畅', '久量', '博深', '舜喆', '中潜', '仙鹤', '威华', '综艺', '大港', '万马', '跃岭', '凯马', '天宸', '拓邦', '雪人', '红相', '开润', '大业', '软控', '华纺', '瀚叶', '金鹰', '仁智', '海亮', '巨化', '闰土', '航民', '兰生', '丰华', '龙头', '申能', '朗姿', '华业', '荣联', '沙钢', '康盛', '龙昌', '哈慈', '龙涤', '瑞德', '锌业', '聚龙', '振静', '尚纬', '川润', '华升', '猴王', '大洲', '九有', '宏业', '中浩', '高乐', '融捷', '兆驰', '兆驰', '特力', '林海', '恒宝', '永鼎', '起步', '信联', '万盛', '银江', '慈星', '海立', '中路', '紫光', '鞍钢', '大商', '辽港', '嘉陵', '锡业', '宏达', '通威', '银亿', '节能', '诚志', '赣能', '光电', '椰岛', '润建', '福达', '华帝', '青松', '安妮', '建发', '鸿博', '永新', '朗源', '仙坛', '东港', '丽鹏', '汉缆', '地矿', '九阳', '万润', '歌尔', '胜利', '联发', '弘业', '杉杉', '波导', '永高', '金固', '华鑫', '申达', '亚通', '世茂', '三孚', '坊展', '河钢', '同方', '首创', '首钢']

# %%
# Observe and obtain common words, manually remove
general_words_list = ['爱慕', '仙鹤', '综艺', '雪人', '大洲', '起步', '锡业', '光电', '地矿', '胜利']
print(general_words_list)
# Out:
# ['爱慕', '仙鹤', '综艺', '雪人', '大洲', '起步', '锡业', '光电', '地矿', '胜利']

# %%
def is_high_quality_with_normal_condition(company_name,company_abbreviation,general_words_list): 
    normal_condition_1 = company_abbreviation not in general_words_list # 如果abbreviation是常用词，则不对本条生成别名对应字典条目
    normal_condition_2 = company_name not in company_abbreviation # 如果name包含在abbreviateviation里面，则不对本条生成别名对应字典条目
    normal_condition_3 = "退市" not in company_name # 如果name里有退市，则不对本条生成别名对应字典条目
    return normal_condition_1 and normal_condition_2 and normal_condition_3

# %% [markdown]
# #### 2) Quality Assessment Using Similarity

# %%
# Create the Trigger Words Set of A_share Company name
with open("News_input\\A_share_list\\A_share_list_with_abbreviation.json", "r", encoding="utf-8") as file:
    a_share_list = json.load(file)

# %%
company_names = [company["name"] for company in a_share_list]

# %%
company_abbreviation = [company["abbreviation"] for company in a_share_list]

# %%
from transformers import BertTokenizer, BertModel
import torch
from sklearn.metrics.pairwise import cosine_similarity
import tqdm
from tqdm import tqdm

# Load BERT model and tokenizer
model_name = "bert-base-chinese"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

# Convert stock names and abbreviations to embeddings
company_names = [company["name"] for company in a_share_list]
company_abbreviations = [company["abbreviation"] for company in a_share_list]

# Define a function to compute embeddings
def get_embedding(text):
    tokens = tokenizer.encode(text, add_special_tokens=True, return_tensors='pt')
    
    with torch.no_grad():
        outputs = model(tokens)
        last_hidden_states = outputs.last_hidden_state
    return last_hidden_states.mean(dim=1).squeeze().numpy()

# Obtain embeddings for stock names and abbreviations
print("Name Embeddings Generation Begins")
name_embeddings = []
for i in tqdm(range(len(company_names))):
    name_embedding_i = get_embedding(company_names[i])
    name_embeddings.append(name_embedding_i)

print("Abbreviation Embeddings Generation Begins")
abbreviation_embeddings = []
for i in tqdm(range(len(company_names))):
    abbreviations_embedding_i = get_embedding(company_abbreviations[i])
    abbreviation_embeddings.append(abbreviations_embedding_i)
# Out:
# Name Embeddings Generation Begins
# 100%|██████████████████████████████████████████████████████████████████████████████| 4654/4654 [02:40<00:00, 28.96it/s]
# Abbreviation Embeddings Generation Begins
# 100%|██████████████████████████████████████████████████████████████████████████████| 4654/4654 [02:56<00:00, 26.37it/s]

# %%
# Calculate similarity
similarity_dict = {}
for i, name_embedding in enumerate(name_embeddings):
    abbr_embedding = abbreviation_embeddings[i]
    # Similarity Calculation
    similarity = cosine_similarity([name_embedding], [abbr_embedding])[0][0]
    similarity_dict[company_names[i]] = similarity

# %%
def is_high_quality_with_similarity_condition(company_name,similarity_dict): 
    similarity_dict[company_name] > 0.7
    return True

# %% [markdown]
# #### 3) Generate High-Quality Abbreviation Using the Above Two Judgment Methods

# %%
import json

# Read in the JSON File of "A_share Company Information"
with open("News_input\\A_share_list\\A_share_list_with_abbreviation.json", "r", encoding="utf-8") as file:
    a_share_list = json.load(file)

# Generate the second lecel filter dictionary
company_dict = {}
for company in a_share_list:
    company_name = company["name"]
    company_abbreviation = company["abbreviation"]
    if is_high_quality_with_similarity_condition(company_name,similarity_dict) and is_high_quality_with_normal_condition(company_name,company_abbreviation,general_words_list):
        company_dict[company_name] = company_abbreviation

# %%
print(f"Size of the second lecel filter dictionary is {len(company_dict)}")
# Out:
# Size of the second lecel filter dictionary is 1574

# %%
# Prevent duplicates
def find_duplicate_companies(company_dict):
    seen = set()
    duplicate_companies = set()
    for company_name, company_abbreviation in company_dict.items():
        if company_name in seen:
            duplicate_companies.add(company_name)
        else:
            seen.add(company_name)

    return duplicate_companies

duplicate_companies = find_duplicate_companies(company_dict)
print("Number of duplicate company names:", len(duplicate_companies))
# Out:
# Number of duplicate company names: 0

# %%
# Invert the dictionary for easier mapping to display explicit_company
inverted_company_dict = {v: k for k, v in company_dict.items()}

# %% [markdown]
# ### 2.3. Second Level filter

# %%
company_set = set()
for company_name, company_abbreviation in company_dict.items():
    company_set.add(company_abbreviation)

print("The number of company name: {}".format(len(company_set)))
print("The number of company name to be searched: {}".format(len(company_set)))
# Out:
# The number of company name: 1568
# The number of company name to be searched: 1568

# %%
from concurrent.futures import ThreadPoolExecutor
# from tqdm import tqdm
import pandas as pd
import threading

# Create a global lock for ensuring thread safety
lock = threading.Lock()

# Function to process a row of data
def process_row(row, company_set, result_list, drop_list):
    title = row["Title"]
    news_content = row["NewsContent"]
   
    if pd.notna(title) and pd.notna(news_content):      
        news = title + news_content
        if any(company in news for company in company_set):
            # Combine the four columns of this row into one
            combined_row = {
                "NewsID": row["NewsID"],
                "Title": title,
                "NewsContent": news_content,
                "NewsSource": row["NewsSource"],
            }
            with lock:
                result_list.append(combined_row)  # Add rows meeting the condition to the result list
        else:
            # Combine the four columns of this row into one
            combined_row = {
                "NewsID": row["NewsID"],
                "Title": title,
                "NewsContent": news_content,
                "NewsSource": row["NewsSource"]
            }
            with lock:
                drop_list.append(combined_row)  # Add rows meeting the condition to the result list

# Main processing function
def process_data(start, end, full_data, company_set, result_list, drop_list):
    for i in range(start, end):
        if i % 1000 == 0:
            print("{} rows have been done".format(i))
            print("--- ")
        process_row(full_data.iloc[i], company_set, result_list, drop_list)

# %%
# read Excel file News_2nd_filting_set
full_data = pd.read_excel("News_input\\News_2nd_filting_set.xlsx")

# %%
# Splitting the data into chunks
num_threads = 21  # Specifying the number of threads
chunk_size = len(full_data) // num_threads

threads = []
result_list = []
drop_list = []
print("Processing data with {} threads...".format(num_threads))

for i in range(num_threads):
    start = i * chunk_size
    end = (i + 1) * chunk_size if i < num_threads - 1 else len(full_data)
    thread = threading.Thread(target=process_data, args=(start, end, full_data, company_set, result_list, drop_list))
    threads.append(thread)
    print("Thread {} is processing rows {} to {}...".format(i + 1, start, end))
    
for thread in threads:
    thread.start()

for thread in threads:
    thread.join()

print("All threads have finished processing.\n")

print("Before selection by Rule, number of news is: {}".format(len(full_data)))
print("After selection by Rule, number of news is: {}".format(len(result_list)))
print("Dropped by Rule, number of news is: {}".format(len(drop_list)))

# Merging the results
result_df = pd.concat([pd.DataFrame(result_list)])
drop_df = pd.concat([pd.DataFrame(drop_list)])
# Out:
# Processing data with 21 threads...
# Thread 1 is processing rows 0 to 26732...
# Thread 2 is processing rows 26732 to 53464...
# Thread 3 is processing rows 53464 to 80196...
# Thread 4 is processing rows 80196 to 106928...
# Thread 5 is processing rows 106928 to 133660...
# Thread 6 is processing rows 133660 to 160392...
# Thread 7 is processing rows 160392 to 187124...
# Thread 8 is processing rows 187124 to 213856...
# Thread 9 is processing rows 213856 to 240588...
# Thread 10 is processing rows 240588 to 267320...
# Thread 11 is processing rows 267320 to 294052...
# Thread 12 is processing rows 294052 to 320784...
# Thread 13 is processing rows 320784 to 347516...
# Thread 14 is processing rows 347516 to 374248...
# Thread 15 is processing rows 374248 to 400980...
# Thread 16 is processing rows 400980 to 427712...
# Thread 17 is processing rows 427712 to 454444...
# Thread 18 is processing rows 454444 to 481176...
# Thread 19 is processing rows 481176 to 507908...
# Thread 20 is processing rows 507908 to 534640...
# Thread 21 is processing rows 534640 to 561372...
# 0 rows have been done
# ---
# 107000 rows have been done
# ---
# 27000 rows have been done
# ---
# 134000 rows have been done
# ---
# 214000 rows have been done
# ---
# 54000 rows have been done
# ---
# 81000 rows have been done
# ---
# 1000 rows have been done
# ---
# 108000 rows have been done
# ---
# 188000 rows have been done
# ---
# 321000 rows have been done
# ---
# 241000 rows have been done
# ---
# 215000 rows have been done
# ---
# 82000 rows have been done
# ---
# 401000 rows have been done
# ---
# 2000 rows have been done
# ---
# 161000 rows have been done
# ---
# 508000 rows have been done
# ---
# 55000 rows have been done
# ---
# 428000 rows have been done
# ---
# 268000 rows have been done
# ---
# 535000 rows have been done
# ---
# 28000 rows have been done
# ---
# 109000 rows have been done
# ---
# 189000 rows have been done
# ---
# 348000 rows have been done
# ---
# 295000 rows have been done
# ---
# 455000 rows have been done
# ---
# 135000 rows have been done
# ---
# 375000 rows have been done
# ---
# 482000 rows have been done
# ---
# 322000 rows have been done
# ---
# 216000 rows have been done
# ---
# 83000 rows have been done
# ---
# 242000 rows have been done
# ---
# 402000 rows have been done
# ---
# 3000 rows have been done
# ---
# 162000 rows have been done
# ---
# 509000 rows have been done
# ---
# 56000 rows have been done
# ---
# 429000 rows have been done
# ---
# 269000 rows have been done
# ---
# 536000 rows have been done
# ---
# 29000 rows have been done
# ---
# 110000 rows have been done
# ---
# 190000 rows have been done
# ---
# 349000 rows have been done
# ---
# 296000 rows have been done
# ---
# 456000 rows have been done
# ---
# 136000 rows have been done
# ---
# 376000 rows have been done
# ---
# 483000 rows have been done
# ---
# 323000 rows have been done
# ---
# 217000 rows have been done
# ---
# 84000 rows have been done
# ---
# 243000 rows have been done
# ---
# 403000 rows have been done
# ---
# 4000 rows have been done
# ---
# 163000 rows have been done
# ---
# 510000 rows have been done
# ---
# 57000 rows have been done
# ---
# 430000 rows have been done
# ---
# 270000 rows have been done
# ---
# 537000 rows have been done
# ---
# 30000 rows have been done
# ---
# 111000 rows have been done
# ---
# 191000 rows have been done
# ---
# 350000 rows have been done
# ---
# 297000 rows have been done
# ---
# 457000 rows have been done
# ---
# 137000 rows have been done
# ---
# 377000 rows have been done
# ---
# 484000 rows have been done
# ---
# 324000 rows have been done
# ---
# 218000 rows have been done
# ---
# 85000 rows have been done
# ---
# 244000 rows have been done
# ---
# 404000 rows have been done
# ---
# 5000 rows have been done
# ---
# 164000 rows have been done
# ---
# 511000 rows have been done
# ---
# 58000 rows have been done
# ---
# 431000 rows have been done
# ---
# 271000 rows have been done
# ---
# 538000 rows have been done
# ---
# 31000 rows have been done
# ---
# 112000 rows have been done
# ---
# 192000 rows have been done
# ---
# 351000 rows have been done
# ---
# 298000 rows have been done
# ---
# 458000 rows have been done
# ---
# 138000 rows have been done
# ---
# 378000 rows have been done
# ---
# 485000 rows have been done
# ---
# 325000 rows have been done
# ---
# 219000 rows have been done
# ---
# 86000 rows have been done
# ---
# 245000 rows have been done
# ---
# 405000 rows have been done
# ---
# 6000 rows have been done
# ---
# 165000 rows have been done
# ---
# 512000 rows have been done
# ---
# 59000 rows have been done
# ---
# 432000 rows have been done
# ---
# 272000 rows have been done
# ---
# 539000 rows have been done
# ---
# 32000 rows have been done
# ---
# 113000 rows have been done
# ---
# 193000 rows have been done
# ---
# 352000 rows have been done
# ---
# 299000 rows have been done
# ---
# 459000 rows have been done
# ---
# 139000 rows have been done
# ---
# 379000 rows have been done
# ---
# 486000 rows have been done
# ---
# 326000 rows have been done
# ---
# 220000 rows have been done
# ---
# 87000 rows have been done
# ---
# 246000 rows have been done
# ---
# 406000 rows have been done
# ---
# 7000 rows have been done
# ---
# 166000 rows have been done
# ---
# 513000 rows have been done
# ---
# 60000 rows have been done
# ---
# 433000 rows have been done
# ---
# 273000 rows have been done
# ---
# 540000 rows have been done
# ---
# 33000 rows have been done
# ---
# 114000 rows have been done
# ---
# 194000 rows have been done
# ---
# 353000 rows have been done
# ---
# 300000 rows have been done
# ---
# 460000 rows have been done
# ---
# 140000 rows have been done
# ---
# 380000 rows have been done
# ---
# 487000 rows have been done
# ---
# 327000 rows have been done
# ---
# 221000 rows have been done
# ---
# 88000 rows have been done
# ---
# 247000 rows have been done
# ---
# 407000 rows have been done
# ---
# 8000 rows have been done
# ---
# 167000 rows have been done
# ---
# 514000 rows have been done
# ---
# 61000 rows have been done
# ---
# 434000 rows have been done
# ---
# 274000 rows have been done
# ---
# 541000 rows have been done
# ---
# 34000 rows have been done
# ---
# 115000 rows have been done
# ---
# 195000 rows have been done
# ---
# 354000 rows have been done
# ---
# 301000 rows have been done
# ---
# 461000 rows have been done
# ---
# 141000 rows have been done
# ---
# 381000 rows have been done
# ---
# 488000 rows have been done
# ---
# 328000 rows have been done
# ---
# 222000 rows have been done
# ---
# 89000 rows have been done
# ---
# 248000 rows have been done
# ---
# 408000 rows have been done
# ---
# 9000 rows have been done
# ---
# 168000 rows have been done
# ---
# 515000 rows have been done
# ---
# 62000 rows have been done
# ---
# 435000 rows have been done
# ---
# 275000 rows have been done
# ---
# 542000 rows have been done
# ---
# 116000 rows have been done
# ---
# 35000 rows have been done
# ---
# 196000 rows have been done
# ---
# 355000 rows have been done
# ---
# 302000 rows have been done
# ---
# 462000 rows have been done
# ---
# 142000 rows have been done
# ---
# 382000 rows have been done
# ---
# 489000 rows have been done
# ---
# 329000 rows have been done
# ---
# 223000 rows have been done
# ---
# 90000 rows have been done
# ---
# 249000 rows have been done
# ---
# 409000 rows have been done
# ---
# 10000 rows have been done
# ---
# 169000 rows have been done
# ---
# 516000 rows have been done
# ---
# 63000 rows have been done
# ---
# 436000 rows have been done
# ---
# 276000 rows have been done
# ---
# 543000 rows have been done
# ---
# 117000 rows have been done
# ---
# 36000 rows have been done
# ---
# 197000 rows have been done
# ---
# 356000 rows have been done
# ---
# 303000 rows have been done
# ---
# 463000 rows have been done
# ---
# 143000 rows have been done
# ---
# 383000 rows have been done
# ---
# 490000 rows have been done
# ---
# 330000 rows have been done
# ---
# 224000 rows have been done
# ---
# 91000 rows have been done
# ---
# 250000 rows have been done
# ---
# 410000 rows have been done
# ---
# 11000 rows have been done
# ---
# 170000 rows have been done
# ---
# 517000 rows have been done
# ---
# 64000 rows have been done
# ---
# 437000 rows have been done
# ---
# 277000 rows have been done
# ---
# 544000 rows have been done
# ---
# 118000 rows have been done
# ---
# 37000 rows have been done
# ---
# 198000 rows have been done
# ---
# 357000 rows have been done
# ---
# 304000 rows have been done
# ---
# 464000 rows have been done
# ---
# 144000 rows have been done
# ---
# 384000 rows have been done
# ---
# 491000 rows have been done
# ---
# 331000 rows have been done
# ---
# 225000 rows have been done
# ---
# 92000 rows have been done
# ---
# 251000 rows have been done
# ---
# 411000 rows have been done
# ---
# 12000 rows have been done
# ---
# 171000 rows have been done
# ---
# 518000 rows have been done
# ---
# 65000 rows have been done
# ---
# 438000 rows have been done
# ---
# 278000 rows have been done
# ---
# 545000 rows have been done
# ---
# 119000 rows have been done
# ---
# 38000 rows have been done
# ---
# 199000 rows have been done
# ---
# 358000 rows have been done
# ---
# 305000 rows have been done
# ---
# 465000 rows have been done
# ---
# 145000 rows have been done
# ---
# 385000 rows have been done
# ---
# 492000 rows have been done
# ---
# 332000 rows have been done
# ---
# 226000 rows have been done
# ---
# 93000 rows have been done
# ---
# 252000 rows have been done
# ---
# 412000 rows have been done
# ---
# 13000 rows have been done
# ---
# 172000 rows have been done
# ---
# 519000 rows have been done
# ---
# 66000 rows have been done
# ---
# 439000 rows have been done
# ---
# 279000 rows have been done
# ---
# 546000 rows have been done
# ---
# 120000 rows have been done
# ---
# 39000 rows have been done
# ---
# 200000 rows have been done
# ---
# 359000 rows have been done
# ---
# 306000 rows have been done
# ---
# 466000 rows have been done
# ---
# 146000 rows have been done
# ---
# 386000 rows have been done
# ---
# 493000 rows have been done
# ---
# 333000 rows have been done
# ---
# 227000 rows have been done
# ---
# 94000 rows have been done
# ---
# 253000 rows have been done
# ---
# 413000 rows have been done
# ---
# 14000 rows have been done
# ---
# 173000 rows have been done
# ---
# 520000 rows have been done
# ---
# 67000 rows have been done
# ---
# 440000 rows have been done
# ---
# 280000 rows have been done
# ---
# 547000 rows have been done
# ---
# 121000 rows have been done
# ---
# 40000 rows have been done
# ---
# 201000 rows have been done
# ---
# 360000 rows have been done
# ---
# 307000 rows have been done
# ---
# 467000 rows have been done
# ---
# 147000 rows have been done
# ---
# 387000 rows have been done
# ---
# 494000 rows have been done
# ---
# 334000 rows have been done
# ---
# 228000 rows have been done
# ---
# 95000 rows have been done
# ---
# 254000 rows have been done
# ---
# 414000 rows have been done
# ---
# 15000 rows have been done
# ---
# 174000 rows have been done
# ---
# 521000 rows have been done
# ---
# 68000 rows have been done
# ---
# 441000 rows have been done
# ---
# 281000 rows have been done
# ---
# 548000 rows have been done
# ---
# 122000 rows have been done
# ---
# 41000 rows have been done
# ---
# 202000 rows have been done
# ---
# 361000 rows have been done
# ---
# 308000 rows have been done
# ---
# 468000 rows have been done
# ---
# 148000 rows have been done
# ---
# 388000 rows have been done
# ---
# 495000 rows have been done
# ---
# 335000 rows have been done
# ---
# 229000 rows have been done
# ---
# 96000 rows have been done
# ---
# 255000 rows have been done
# ---
# 415000 rows have been done
# ---
# 16000 rows have been done
# ---
# 175000 rows have been done
# ---
# 522000 rows have been done
# ---
# 69000 rows have been done
# ---
# 442000 rows have been done
# ---
# 282000 rows have been done
# ---
# 549000 rows have been done
# ---
# 123000 rows have been done
# ---
# 42000 rows have been done
# ---
# 203000 rows have been done
# ---
# 362000 rows have been done
# ---
# 309000 rows have been done
# ---
# 469000 rows have been done
# ---
# 149000 rows have been done
# ---
# 389000 rows have been done
# ---
# 496000 rows have been done
# ---
# 336000 rows have been done
# ---
# 230000 rows have been done
# ---
# 97000 rows have been done
# ---
# 256000 rows have been done
# ---
# 416000 rows have been done
# ---
# 17000 rows have been done
# ---
# 176000 rows have been done
# ---
# 523000 rows have been done
# ---
# 70000 rows have been done
# ---
# 443000 rows have been done
# ---
# 283000 rows have been done
# ---
# 550000 rows have been done
# ---
# 124000 rows have been done
# ---
# 43000 rows have been done
# ---
# 204000 rows have been done
# ---
# 363000 rows have been done
# ---
# 310000 rows have been done
# ---
# 470000 rows have been done
# ---
# 150000 rows have been done
# ---
# 390000 rows have been done
# ---
# 497000 rows have been done
# ---
# 337000 rows have been done
# ---
# 231000 rows have been done
# ---
# 98000 rows have been done
# ---
# 257000 rows have been done
# ---
# 417000 rows have been done
# ---
# 18000 rows have been done
# ---
# 177000 rows have been done
# ---
# 524000 rows have been done
# ---
# 71000 rows have been done
# ---
# 444000 rows have been done
# ---
# 284000 rows have been done
# ---
# 551000 rows have been done
# ---
# 125000 rows have been done
# ---
# 44000 rows have been done
# ---
# 205000 rows have been done
# ---
# 364000 rows have been done
# ---
# 311000 rows have been done
# ---
# 471000 rows have been done
# ---
# 151000 rows have been done
# ---
# 391000 rows have been done
# ---
# 498000 rows have been done
# ---
# 338000 rows have been done
# ---
# 232000 rows have been done
# ---
# 99000 rows have been done
# ---
# 258000 rows have been done
# ---
# 418000 rows have been done
# ---
# 19000 rows have been done
# ---
# 178000 rows have been done
# ---
# 525000 rows have been done
# ---
# 72000 rows have been done
# ---
# 445000 rows have been done
# ---
# 285000 rows have been done
# ---
# 552000 rows have been done
# ---
# 126000 rows have been done
# ---
# 45000 rows have been done
# ---
# 206000 rows have been done
# ---
# 365000 rows have been done
# ---
# 312000 rows have been done
# ---
# 472000 rows have been done
# ---
# 152000 rows have been done
# ---
# 392000 rows have been done
# ---
# 499000 rows have been done
# ---
# 339000 rows have been done
# ---
# 233000 rows have been done
# ---
# 100000 rows have been done
# ---
# 259000 rows have been done
# ---
# 419000 rows have been done
# ---
# 20000 rows have been done
# ---
# 179000 rows have been done
# ---
# 526000 rows have been done
# ---
# 73000 rows have been done
# ---
# 446000 rows have been done
# ---
# 286000 rows have been done
# ---
# 553000 rows have been done
# ---
# 127000 rows have been done
# ---
# 46000 rows have been done
# ---
# 207000 rows have been done
# ---
# 366000 rows have been done
# ---
# 313000 rows have been done
# ---
# 473000 rows have been done
# ---
# 153000 rows have been done
# ---
# 393000 rows have been done
# ---
# 500000 rows have been done
# ---
# 340000 rows have been done
# ---
# 234000 rows have been done
# ---
# 101000 rows have been done
# ---
# 260000 rows have been done
# ---
# 420000 rows have been done
# ---
# 21000 rows have been done
# ---
# 180000 rows have been done
# ---
# 527000 rows have been done
# ---
# 74000 rows have been done
# ---
# 447000 rows have been done
# ---
# 287000 rows have been done
# ---
# 554000 rows have been done
# ---
# 128000 rows have been done
# ---
# 47000 rows have been done
# ---
# 208000 rows have been done
# ---
# 367000 rows have been done
# ---
# 314000 rows have been done
# ---
# 474000 rows have been done
# ---
# 154000 rows have been done
# ---
# 394000 rows have been done
# ---
# 501000 rows have been done
# ---
# 341000 rows have been done
# ---
# 235000 rows have been done
# ---
# 102000 rows have been done
# ---
# 261000 rows have been done
# ---
# 421000 rows have been done
# ---
# 22000 rows have been done
# ---
# 181000 rows have been done
# ---
# 528000 rows have been done
# ---
# 75000 rows have been done
# ---
# 448000 rows have been done
# ---
# 288000 rows have been done
# ---
# 555000 rows have been done
# ---
# 129000 rows have been done
# ---
# 48000 rows have been done
# ---
# 209000 rows have been done
# ---
# 368000 rows have been done
# ---
# 315000 rows have been done
# ---
# 475000 rows have been done
# ---
# 155000 rows have been done
# ---
# 395000 rows have been done
# ---
# 502000 rows have been done
# ---
# 342000 rows have been done
# ---
# 236000 rows have been done
# ---
# 103000 rows have been done
# ---
# 262000 rows have been done
# ---
# 422000 rows have been done
# ---
# 23000 rows have been done
# ---
# 182000 rows have been done
# ---
# 529000 rows have been done
# ---
# 76000 rows have been done
# ---
# 449000 rows have been done
# ---
# 289000 rows have been done
# ---
# 556000 rows have been done
# ---
# 130000 rows have been done
# ---
# 49000 rows have been done
# ---
# 210000 rows have been done
# ---
# 369000 rows have been done
# ---
# 316000 rows have been done
# ---
# 476000 rows have been done
# ---
# 156000 rows have been done
# ---
# 396000 rows have been done
# ---
# 503000 rows have been done
# ---
# 343000 rows have been done
# ---
# 237000 rows have been done
# ---
# 104000 rows have been done
# ---
# 263000 rows have been done
# ---
# 423000 rows have been done
# ---
# 24000 rows have been done
# ---
# 183000 rows have been done
# ---
# 530000 rows have been done
# ---
# 77000 rows have been done
# ---
# 450000 rows have been done
# ---
# 290000 rows have been done
# ---
# 557000 rows have been done
# ---
# 131000 rows have been done
# ---
# 50000 rows have been done
# ---
# 211000 rows have been done
# ---
# 370000 rows have been done
# ---
# 317000 rows have been done
# ---
# 477000 rows have been done
# ---
# 157000 rows have been done
# ---
# 397000 rows have been done
# ---
# 504000 rows have been done
# ---
# 344000 rows have been done
# ---
# 238000 rows have been done
# ---
# 105000 rows have been done
# ---
# 264000 rows have been done
# ---
# 424000 rows have been done
# ---
# 25000 rows have been done
# ---
# 184000 rows have been done
# ---
# 531000 rows have been done
# ---
# 78000 rows have been done
# ---
# 451000 rows have been done
# ---
# 291000 rows have been done
# ---
# 558000 rows have been done
# ---
# 132000 rows have been done
# ---
# 51000 rows have been done
# ---
# 212000 rows have been done
# ---
# 371000 rows have been done
# ---
# 318000 rows have been done
# ---
# 478000 rows have been done
# ---
# 158000 rows have been done
# ---
# 398000 rows have been done
# ---
# 345000 rows have been done
# ---
# 505000 rows have been done
# ---
# 239000 rows have been done
# ---
# 106000 rows have been done
# ---
# 265000 rows have been done
# ---
# 425000 rows have been done
# ---
# 26000 rows have been done
# ---
# 185000 rows have been done
# ---
# 532000 rows have been done
# ---
# 79000 rows have been done
# ---
# 452000 rows have been done
# ---
# 292000 rows have been done
# ---
# 559000 rows have been done
# ---
# 133000 rows have been done
# ---
# 52000 rows have been done
# ---
# 213000 rows have been done
# ---
# 372000 rows have been done
# ---
# 319000 rows have been done
# ---
# 479000 rows have been done
# ---
# 159000 rows have been done
# ---
# 399000 rows have been done
# ---
# 346000 rows have been done
# ---
# 506000 rows have been done
# ---
# 240000 rows have been done
# ---
# 266000 rows have been done
# ---
# 426000 rows have been done
# ---
# 186000 rows have been done
# ---
# 533000 rows have been done
# ---
# 80000 rows have been done
# ---
# 453000 rows have been done
# ---
# 293000 rows have been done
# ---
# 560000 rows have been done
# ---
# 53000 rows have been done
# ---
# 373000 rows have been done
# ---
# 320000 rows have been done
# ---
# 480000 rows have been done
# ---
# 160000 rows have been done
# ---
# 400000 rows have been done
# ---
# 347000 rows have been done
# ---
# 507000 rows have been done
# ---
# 267000 rows have been done
# ---
# 427000 rows have been done
# ---
# 187000 rows have been done
# ---
# 534000 rows have been done
# ---
# 454000 rows have been done
# ---
# 294000 rows have been done
# ---
# 561000 rows have been done
# ---
# 374000 rows have been done
# ---
# 481000 rows have been done
# ---
# All threads have finished processing.
#
# Before selected by Rule, number of news is: 561372
# After selected by Rule, number of news is: 48984
# Droped by Rule, number of news is: 512388

# %%
result_df.to_excel("News_output\\News_application_domain_set_part1_withoutCompany.xlsx", index=False)
drop_df.to_excel("News_input\\News_3nd_filting_set.xlsx", index=False)

# %% [markdown]
# ### 2.4. Apply explicit_company to each news in Application domain set

# %%
from concurrent.futures import ThreadPoolExecutor
import pandas as pd
import threading
import json
import jieba
import re

# Define Trie dictionary tree node
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end_of_word = False
        self.company_name = None  # Store the company name

# Create a Trie dictionary tree
def build_trie(company_dict):
    root = TrieNode()
    for key,company_abbreviation in company_dict.items():
        node = root
        name = company_abbreviation
        for char in name:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]
        node.is_end_of_word = True
        node.company_name = name  # Store the company name
    return root

# Function to extract companies from text
def extract_companies_from_text(text, trie_root, inverted_company_dict):
    companies = set()
    def search_trie(text, node, inverted_company_dict):
        for i in range(len(text)):
            char = text[i]
            if char in node.children:
                node = node.children[char]
                if node.is_end_of_word:
                    companies.add(inverted_company_dict[node.company_name])
            else:
                break


    for i in range(len(text)):
        search_trie(text[i:], trie_root, inverted_company_dict)

    return companies

# %%
# Create a Trie dictionary tree
a_share_trie = build_trie(company_dict)

# %%
# Updated extraction_row function
def extraction_row(row, trie_root, inverted_company_dict):
    title = row["Title"]
    news_content = row["NewsContent"]
    news = title + news_content

    matched_company_names = extract_companies_from_text(news, trie_root, inverted_company_dict)

    # Converting the matched company names set into a comma-separated string
    matched_company_names_str = ", ".join(matched_company_names)

    return {
        "NewsID": row["NewsID"],
        "Title": title,
        "NewsContent": news_content,
        "NewsSource": row["NewsSource"],
        "Explicit_Company": matched_company_names_str  # Extracted matched company names
    }

# Main processing function
def extraction_data(start, end, full_data, trie_root, extraction_list, inverted_company_dict):
    for i in range(start, end):
        if i % 100 == 0:
            print("--- {} rows have been done ---".format(i))
        combined_row = extraction_row(full_data.iloc[i], trie_root, inverted_company_dict)
        with lock:
            extraction_list.append(combined_row)

# %%
withoutCompany_df = pd.read_excel("News_output\\News_application_domain_set_part1_withoutCompany.xlsx")

# %%
# Create a global lock for ensuring thread safety
lock = threading.Lock()
# Splitting data chunks
num_threads = 20  # Specify the number of threads
chunk_size = len(withoutCompany_df) // num_threads

threads = []
extraction_list = []
print("Processing data with {} threads...".format(num_threads))

for i in range(num_threads):
    start = i * chunk_size
    end = (i + 1) * chunk_size if i < num_threads - 1 else len(withoutCompany_df)
    thread = threading.Thread(target=extraction_data, args=(start, end, withoutCompany_df, a_share_trie, extraction_list, inverted_company_dict))
    threads.append(thread)
    print("Thread {} is processing rows {} to {}...".format(i + 1, start, end))
    
for thread in threads:
    thread.start()

for thread in threads:
    thread.join()

print("All threads have finished processing.\n")

# Merge results
extraction_df = pd.concat([pd.DataFrame(extraction_list)])
# Out:
# Processing data with 20 threads...
# Thread 1 is processing rows 0 to 2449...
# Thread 2 is processing rows 2449 to 4898...
# Thread 3 is processing rows 4898 to 7347...
# Thread 4 is processing rows 7347 to 9796...
# Thread 5 is processing rows 9796 to 12245...
# Thread 6 is processing rows 12245 to 14694...
# Thread 7 is processing rows 14694 to 17143...
# Thread 8 is processing rows 17143 to 19592...
# Thread 9 is processing rows 19592 to 22041...
# Thread 10 is processing rows 22041 to 24490...
# Thread 11 is processing rows 24490 to 26939...
# Thread 12 is processing rows 26939 to 29388...
# Thread 13 is processing rows 29388 to 31837...
# Thread 14 is processing rows 31837 to 34286...
# Thread 15 is processing rows 34286 to 36735...
# Thread 16 is processing rows 36735 to 39184...
# Thread 17 is processing rows 39184 to 41633...
# Thread 18 is processing rows 41633 to 44082...
# Thread 19 is processing rows 44082 to 46531...
# Thread 20 is processing rows 46531 to 48984...
# --- 0 rows have been done ---
# --- 2500 rows have been done ---
# --- 100 rows have been done ------ 2600 rows have been done ---
# --- 4900 rows have been done ---
#
# --- 5000 rows have been done ---
# --- 2700 rows have been done ---
# --- 7400 rows have been done ---
# --- 200 rows have been done ---
# --- 5100 rows have been done ---
# --- 7500 rows have been done ---
# --- 7600 rows have been done ---
# --- 9800 rows have been done ---
# --- 5200 rows have been done ---
# --- 2800 rows have been done ---
# --- 9900 rows have been done ---
# --- 300 rows have been done ---
# --- 7700 rows have been done ---
# --- 5300 rows have been done ---
# --- 2900 rows have been done ---
# --- 7800 rows have been done ---
# --- 5400 rows have been done ---
# --- 12300 rows have been done ---
# --- 400 rows have been done ---
# --- 7900 rows have been done ---
# --- 3000 rows have been done ---
# --- 8000 rows have been done ---
# --- 14700 rows have been done ---
# --- 500 rows have been done ---
# --- 8100 rows have been done ---
# --- 10000 rows have been done ---
# --- 5500 rows have been done ---
# --- 14800 rows have been done ---
# --- 8200 rows have been done ---
# --- 12400 rows have been done ---
# --- 5600 rows have been done ---
# --- 10100 rows have been done ---
# --- 17200 rows have been done ---
# --- 8300 rows have been done ---
# --- 5700 rows have been done ---
# --- 14900 rows have been done ---
# --- 17300 rows have been done ---
# --- 19600 rows have been done ---
# --- 8400 rows have been done ---
# --- 10200 rows have been done ---
# --- 15000 rows have been done ---
# --- 12500 rows have been done ---
# --- 5800 rows have been done ---
# --- 8500 rows have been done ---
# --- 3100 rows have been done ---
# --- 15100 rows have been done ---
# --- 5900 rows have been done ---
# --- 17400 rows have been done ---
# --- 600 rows have been done ---
# --- 15200 rows have been done ---
# --- 17500 rows have been done ---
# --- 12600 rows have been done ---
# --- 8600 rows have been done ---
# --- 6000 rows have been done ---
# --- 19700 rows have been done ---
# --- 17600 rows have been done ------ 3200 rows have been done ---
# --- 8700 rows have been done ---
# --- 6100 rows have been done ---
#
# --- 10300 rows have been done ---
# --- 700 rows have been done ---
# --- 15300 rows have been done ---
# --- 12700 rows have been done ---
# --- 22100 rows have been done ---
# --- 8800 rows have been done ---
# --- 24500 rows have been done ---
# --- 17700 rows have been done ---
# --- 19800 rows have been done ---
# --- 24600 rows have been done ---
# --- 12800 rows have been done ---
# --- 22200 rows have been done ---
# --- 15400 rows have been done ---
# --- 10400 rows have been done ---
# --- 6200 rows have been done ------ 3300 rows have been done ---
#
# --- 800 rows have been done ---
# --- 19900 rows have been done ---
# --- 17800 rows have been done ---
# --- 12900 rows have been done ---
# --- 15500 rows have been done ---
# --- 10500 rows have been done ---
# --- 8900 rows have been done ---
# --- 6300 rows have been done ---
# --- 900 rows have been done ---
# --- 3400 rows have been done ---
# --- 24700 rows have been done ---
# --- 27000 rows have been done ---
# --- 29400 rows have been done ---
# --- 34300 rows have been done ---
# --- 39200 rows have been done ---
# --- 44100 rows have been done ---
# --- 15600 rows have been done ---
# --- 22300 rows have been done ---
# --- 31900 rows have been done ---
# --- 27100 rows have been done ---
# --- 36800 rows have been done ---
# --- 13000 rows have been done ---
# --- 41700 rows have been done ---
# --- 46600 rows have been done ---
# --- 20000 rows have been done ---
# --- 6400 rows have been done ---
# --- 1000 rows have been done ---
# --- 24800 rows have been done ---
# --- 17900 rows have been done ---
# --- 10600 rows have been done ---
# --- 9000 rows have been done ---
# --- 3500 rows have been done ---
# --- 29500 rows have been done ---
# --- 34400 rows have been done ---
# --- 39300 rows have been done ---
# --- 44200 rows have been done ---
# --- 15700 rows have been done ---
# --- 22400 rows have been done ---
# --- 32000 rows have been done ---
# --- 27200 rows have been done ---
# --- 36900 rows have been done ---
# --- 13100 rows have been done ---
# --- 41800 rows have been done ---
# --- 46700 rows have been done ---
# --- 20100 rows have been done ---
# --- 6500 rows have been done ---
# --- 1100 rows have been done ---
# --- 24900 rows have been done ---
# --- 18000 rows have been done ---
# --- 10700 rows have been done ---
# --- 9100 rows have been done ---
# --- 3600 rows have been done ---
# --- 29600 rows have been done ---
# --- 34500 rows have been done ---
# --- 39400 rows have been done ---
# --- 44300 rows have been done ---
# --- 15800 rows have been done ---
# --- 22500 rows have been done ---
# --- 32100 rows have been done ---
# --- 27300 rows have been done ---
# --- 37000 rows have been done ---
# --- 13200 rows have been done ---
# --- 41900 rows have been done ---
# --- 46800 rows have been done ---
# --- 20200 rows have been done ---
# --- 6600 rows have been done ---
# --- 1200 rows have been done ---
# --- 25000 rows have been done ---
# --- 18100 rows have been done ---
# --- 10800 rows have been done ---
# --- 9200 rows have been done ---
# --- 3700 rows have been done ---
# --- 29700 rows have been done ---
# --- 34600 rows have been done ---
# --- 39500 rows have been done ---
# --- 44400 rows have been done ---
# --- 15900 rows have been done ---
# --- 22600 rows have been done ---
# --- 32200 rows have been done ---
# --- 27400 rows have been done ---
# --- 37100 rows have been done ---
# --- 13300 rows have been done ---
# --- 42000 rows have been done ---
# --- 46900 rows have been done ---
# --- 20300 rows have been done ---
# --- 6700 rows have been done ---
# --- 1300 rows have been done ---
# --- 25100 rows have been done ---
# --- 18200 rows have been done ---
# --- 10900 rows have been done ---
# --- 9300 rows have been done ---
# --- 3800 rows have been done ---
# --- 29800 rows have been done ---
# --- 34700 rows have been done ---
# --- 39600 rows have been done ---
# --- 44500 rows have been done ---
# --- 16000 rows have been done ---
# --- 22700 rows have been done ---
# --- 32300 rows have been done ---
# --- 27500 rows have been done ---
# --- 37200 rows have been done ---
# --- 13400 rows have been done ---
# --- 42100 rows have been done ---
# --- 47000 rows have been done ---
# --- 20400 rows have been done ---
# --- 6800 rows have been done ---
# --- 1400 rows have been done ---
# --- 25200 rows have been done ---
# --- 18300 rows have been done ---
# --- 11000 rows have been done ---
# --- 9400 rows have been done ---
# --- 3900 rows have been done ---
# --- 29900 rows have been done ---
# --- 34800 rows have been done ---
# --- 39700 rows have been done ---
# --- 44600 rows have been done ---
# --- 16100 rows have been done ---
# --- 22800 rows have been done ---
# --- 32400 rows have been done ---
# --- 27600 rows have been done ---
# --- 37300 rows have been done ---
# --- 13500 rows have been done ---
# --- 42200 rows have been done ---
# --- 47100 rows have been done ---
# --- 20500 rows have been done ---
# --- 6900 rows have been done ---
# --- 1500 rows have been done ---
# --- 25300 rows have been done ---
# --- 18400 rows have been done ---
# --- 11100 rows have been done ---
# --- 9500 rows have been done ---
# --- 4000 rows have been done ---
# --- 30000 rows have been done ---
# --- 34900 rows have been done ---
# --- 39800 rows have been done ---
# --- 44700 rows have been done ---
# --- 16200 rows have been done ---
# --- 22900 rows have been done ---
# --- 32500 rows have been done ---
# --- 27700 rows have been done ---
# --- 37400 rows have been done ---
# --- 13600 rows have been done ---
# --- 42300 rows have been done ---
# --- 47200 rows have been done ---
# --- 20600 rows have been done ---
# --- 7000 rows have been done ---
# --- 1600 rows have been done ---
# --- 25400 rows have been done ---
# --- 18500 rows have been done ---
# --- 11200 rows have been done ---
# --- 9600 rows have been done ---
# --- 4100 rows have been done ---
# --- 30100 rows have been done ---
# --- 35000 rows have been done ---
# --- 39900 rows have been done ---
# --- 44800 rows have been done ---
# --- 16300 rows have been done ---
# --- 23000 rows have been done ---
# --- 32600 rows have been done ---
# --- 27800 rows have been done ---
# --- 37500 rows have been done ---
# --- 13700 rows have been done ---
# --- 42400 rows have been done ---
# --- 47300 rows have been done ---
# --- 20700 rows have been done ---
# --- 7100 rows have been done ---
# --- 1700 rows have been done ---
# --- 25500 rows have been done ---
# --- 18600 rows have been done ---
# --- 11300 rows have been done ---
# --- 9700 rows have been done ---
# --- 4200 rows have been done ---
# --- 30200 rows have been done ---
# --- 35100 rows have been done ---
# --- 40000 rows have been done ---
# --- 44900 rows have been done ---
# --- 16400 rows have been done ---
# --- 23100 rows have been done ---
# --- 32700 rows have been done ---
# --- 27900 rows have been done ---
# --- 37600 rows have been done ---
# --- 13800 rows have been done ---
# --- 42500 rows have been done ---
# --- 47400 rows have been done ---
# --- 20800 rows have been done ---
# --- 7200 rows have been done ---
# --- 1800 rows have been done ---
# --- 25600 rows have been done ---
# --- 18700 rows have been done ---
# --- 11400 rows have been done ---
# --- 4300 rows have been done ---
# --- 30300 rows have been done ---
# --- 35200 rows have been done ---
# --- 40100 rows have been done ---
# --- 45000 rows have been done ---
# --- 16500 rows have been done ---
# --- 23200 rows have been done ---
# --- 32800 rows have been done ---
# --- 28000 rows have been done ---
# --- 37700 rows have been done ---
# --- 13900 rows have been done ---
# --- 42600 rows have been done ---
# --- 47500 rows have been done ---
# --- 20900 rows have been done ---
# --- 7300 rows have been done ---
# --- 1900 rows have been done ---
# --- 25700 rows have been done ---
# --- 18800 rows have been done ---
# --- 11500 rows have been done ---
# --- 4400 rows have been done ---
# --- 30400 rows have been done ---
# --- 35300 rows have been done ---
# --- 40200 rows have been done ---
# --- 45100 rows have been done ---
# --- 16600 rows have been done ---
# --- 23300 rows have been done ---
# --- 32900 rows have been done ---
# --- 28100 rows have been done ---
# --- 37800 rows have been done ---
# --- 14000 rows have been done ---
# --- 42700 rows have been done ---
# --- 47600 rows have been done ---
# --- 21000 rows have been done ---
# --- 2000 rows have been done ---
# --- 25800 rows have been done ---
# --- 18900 rows have been done ---
# --- 11600 rows have been done ---
# --- 4500 rows have been done ---
# --- 30500 rows have been done ---
# --- 35400 rows have been done ---
# --- 40300 rows have been done ---
# --- 45200 rows have been done ---
# --- 16700 rows have been done ---
# --- 23400 rows have been done ---
# --- 33000 rows have been done ---
# --- 28200 rows have been done ---
# --- 37900 rows have been done ---
# --- 14100 rows have been done ---
# --- 42800 rows have been done ---
# --- 47700 rows have been done ---
# --- 21100 rows have been done ---
# --- 2100 rows have been done ---
# --- 25900 rows have been done ---
# --- 19000 rows have been done ---
# --- 11700 rows have been done ---
# --- 4600 rows have been done ---
# --- 30600 rows have been done ---
# --- 35500 rows have been done ---
# --- 40400 rows have been done ---
# --- 45300 rows have been done ---
# --- 16800 rows have been done ---
# --- 23500 rows have been done ---
# --- 33100 rows have been done ---
# --- 14200 rows have been done ---
# --- 28300 rows have been done ---
# --- 38000 rows have been done ---
# --- 42900 rows have been done ---
# --- 21200 rows have been done ---
# --- 47800 rows have been done ---
# --- 2200 rows have been done ---
# --- 26000 rows have been done ---
# --- 19100 rows have been done ---
# --- 11800 rows have been done ---
# --- 4700 rows have been done ---
# --- 30700 rows have been done ---
# --- 35600 rows have been done ---
# --- 40500 rows have been done ---
# --- 45400 rows have been done ---
# --- 16900 rows have been done ---
# --- 23600 rows have been done ---
# --- 33200 rows have been done ---
# --- 14300 rows have been done ---
# --- 28400 rows have been done ---
# --- 38100 rows have been done ---
# --- 43000 rows have been done ---
# --- 21300 rows have been done ---
# --- 47900 rows have been done ---
# --- 2300 rows have been done ------ 26100 rows have been done ---
#
# --- 19200 rows have been done ---
# --- 11900 rows have been done ---
# --- 4800 rows have been done ---
# --- 30800 rows have been done ---
# --- 35700 rows have been done ---
# --- 40600 rows have been done ---
# --- 45500 rows have been done ---
# --- 17000 rows have been done ---
# --- 23700 rows have been done ---
# --- 33300 rows have been done ---
# --- 14400 rows have been done ---
# --- 28500 rows have been done ---
# --- 38200 rows have been done ---
# --- 43100 rows have been done ---
# --- 21400 rows have been done ---
# --- 48000 rows have been done ---
# --- 26200 rows have been done ---
# --- 2400 rows have been done ---
# --- 19300 rows have been done ---
# --- 12000 rows have been done ---
# --- 30900 rows have been done ---
# --- 35800 rows have been done ---
# --- 40700 rows have been done ---
# --- 45600 rows have been done ---
# --- 17100 rows have been done ---
# --- 23800 rows have been done ---
# --- 33400 rows have been done ---
# --- 14500 rows have been done ---
# --- 28600 rows have been done ---
# --- 38300 rows have been done ---
# --- 43200 rows have been done ---
# --- 21500 rows have been done ---
# --- 48100 rows have been done ---
# --- 26300 rows have been done ---
# --- 19400 rows have been done ---
# --- 12100 rows have been done ---
# --- 31000 rows have been done ---
# --- 35900 rows have been done ---
# --- 40800 rows have been done ---
# --- 45700 rows have been done ---
# --- 23900 rows have been done ---
# --- 33500 rows have been done ---
# --- 14600 rows have been done ---
# --- 28700 rows have been done ---
# --- 38400 rows have been done ---
# --- 43300 rows have been done ---
# --- 21600 rows have been done ---
# --- 48200 rows have been done ---
# --- 26400 rows have been done ---
# --- 19500 rows have been done ---
# --- 12200 rows have been done ---
# --- 31100 rows have been done ---
# --- 36000 rows have been done ---
# --- 40900 rows have been done ---
# --- 45800 rows have been done ---
# --- 24000 rows have been done ---
# --- 33600 rows have been done ---
# --- 28800 rows have been done ---
# --- 38500 rows have been done ---
# --- 43400 rows have been done ---
# --- 21700 rows have been done ---
# --- 48300 rows have been done ---
# --- 26500 rows have been done ---
# --- 31200 rows have been done ---
# --- 36100 rows have been done ---
# --- 41000 rows have been done ---
# --- 45900 rows have been done ---
# --- 24100 rows have been done ---
# --- 33700 rows have been done ---
# --- 28900 rows have been done ---
# --- 38600 rows have been done ---
# --- 43500 rows have been done ---
# --- 21800 rows have been done ---
# --- 48400 rows have been done ---
# --- 26600 rows have been done ---
# --- 31300 rows have been done ---
# --- 36200 rows have been done ---
# --- 41100 rows have been done ---
# --- 46000 rows have been done ---
# --- 24200 rows have been done ---
# --- 33800 rows have been done ---
# --- 29000 rows have been done ---
# --- 38700 rows have been done ---
# --- 43600 rows have been done ---
# --- 21900 rows have been done ---
# --- 48500 rows have been done ---
# --- 26700 rows have been done ---
# --- 31400 rows have been done ------ 36300 rows have been done ---
#
# --- 41200 rows have been done ---
# --- 46100 rows have been done ---
# --- 24300 rows have been done ---
# --- 33900 rows have been done ---
# --- 29100 rows have been done ---
# --- 38800 rows have been done ---
# --- 43700 rows have been done ---
# --- 22000 rows have been done ---
# --- 48600 rows have been done ---
# --- 26800 rows have been done ---
# --- 36400 rows have been done ------ 31500 rows have been done ---
#
# --- 41300 rows have been done ---
# --- 46200 rows have been done ---
# --- 24400 rows have been done ---
# --- 34000 rows have been done ---
# --- 29200 rows have been done ---
# --- 38900 rows have been done ---
# --- 43800 rows have been done ---
# --- 48700 rows have been done ---
# --- 26900 rows have been done ---
# --- 31600 rows have been done ------ 36500 rows have been done ---
#
# --- 41400 rows have been done ---
# --- 46300 rows have been done ---
# --- 34100 rows have been done ---
# --- 29300 rows have been done ---
# --- 39000 rows have been done ---
# --- 43900 rows have been done ---
# --- 48800 rows have been done ---
# --- 36600 rows have been done ------ 31700 rows have been done ---
#
# --- 41500 rows have been done ---
# --- 46400 rows have been done ---
# --- 34200 rows have been done ---
# --- 39100 rows have been done ---
# --- 44000 rows have been done ---
# --- 48900 rows have been done ---
# --- 31800 rows have been done ---
# --- 36700 rows have been done ---
# --- 41600 rows have been done ---
# --- 46500 rows have been done ---
# All threads have finished processing.

# %%
extraction_df.to_excel("News_output\\News_application_domain_set_part1_withCompany.xlsx", index=False)

# %%
import pandas as pd

# Merge News_application_domain_set_part1_withCompany.xlsx and News_training_domain_set_withCompany.xlsx
# Read the first Excel file
df_part1 = pd.read_excel("News_output\\News_application_domain_set_part1_withCompany.xlsx")

# Read the second Excel file
df_part2 = pd.read_excel("News_output\\News_training_domain_set_withCompany.xlsx")

# Concatenate the two DataFrames
df_combined = pd.concat([df_part1, df_part2])

# Sort the combined DataFrame by the "NewsID" column in ascending order
df_combined_sorted = df_combined.sort_values("NewsID", ascending=True)

# Write the merged DataFrame into a new Excel file
df_combined_sorted.to_excel("News_output\\News_application_domain_set_withCompany.xlsx", index=False)

# %% [markdown]
# ### 2.5.filter_rate

# %%
# Read the Qrigin file
df_total_news = pd.read_excel("News_input\\News.xlsx")
# Read the final file of task1 Q1
df_filtered_news= pd.read_excel("News_output\\News_application_domain_set_withCompany.xlsx")

filter_rate = len(df_filtered_news)/len(df_total_news)

# %%
print(f"Number of total news: {len(df_total_news)}")
print(f"Number of filtered news: {len(df_filtered_news)}")
print(f'Filter rate: {filter_rate:.4f}')
# Out:
# Number of total news: 1037035
# Number of filtered news: 524226
# Filter rate: 0.5055

# %% [markdown]
# ---

# %% [markdown]
# ## 3.[Unacceptible] Search by Similarity Slides Window for A Boader Application Domain Set

# %%
# import pandas as pd
# import jieba
# from transformers import BertTokenizer, BertModel
# import torch
# import numpy as np

# # Load the Chinese BERT model
# tokenizer = BertTokenizer.from_pretrained("bert-base-chinese")
# model = BertModel.from_pretrained("bert-base-chinese")

# # Get embeddings for company names
# company_names = [company["name"] for company in a_share_list] 
# name_embeddings = {}
# for company_name in company_names:
#     inputs = tokenizer(company_name, return_tensors="pt", padding=True, truncation=True)
#     outputs = model(**inputs)
#     name_embedding = outputs.last_hidden_state.mean(dim=1).detach().numpy()
#     name_embeddings[company_name] = name_embedding

# # Get embeddings for generated abbreviations
# company_abbreviations = [company["abbreviation"] for company in a_share_list]
# abbreviation_embeddings = {}
# for company_abbreviation in company_abbreviations:
#     inputs = tokenizer(company_abbreviation, return_tensors="pt", padding=True, truncation=True)
#     outputs = model(**inputs)
#     abbreviation_embedding = outputs.last_hidden_state.mean(dim=1).detach().numpy()
#     abbreviation_embeddings[company_name] = abbreviation_embedding    
    
    
# # Define similarity threshold
# similarity_threshold = 0.8


# # Iterate through each news item
# for index, row in news_data.iterrows():
#     # Get news title and content
#     title = row["Title"]
#     news_content = row["NewsContent"]

#     # Concatenate title and content
#     text = title + " " + news_content

#     # Tokenize the text
#     words = jieba.cut(text)

#     # Join the tokenized words into a string
#     text = " ".join(words)

#     # Sliding window processing
#     window_size = 5  # Adjust window size as needed
#     word_list = text.split()
#     for i in range(len(word_list) - window_size + 1):
#         window_text = " ".join(word_list[i:i+window_size])
        
#         # Calculate similarity between the text window and company names
#         max_similarity = 0
#         related_company = None
#         for company_name, company_embedding in company_embeddings.items():
#             inputs = tokenizer(window_text, return_tensors="pt", padding=True, truncation=True)
#             outputs = model(**inputs)
#             window_embedding = outputs.last_hidden_state.mean(dim=1).detach().numpy()
            
#             similarity = np.dot(company_embedding, window_embedding.T).max()

#             if similarity > similarity_threshold and similarity > max_similarity:
#                 max_similarity = similarity
#                 related_company = company_name

#         if related_company is not None:
#             related_words.append(related_company)
#         else:
#             related_words.append(None)

# # Add the column of related words to the data
# news_data["RelatedCompany"] = related_words

# # Save the filtered data to a new Excel file
# news_data.to_excel("NewsWithRelatedCompany.xlsx", index=False)
